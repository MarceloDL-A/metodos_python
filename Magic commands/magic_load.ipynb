# %% [raw]
# https://www.kaggle.com/morrisb/ipython-magic-functions

# %%
# %load https://www.kaggle.com/morrisb/ipython-magic-functions
<!DOCTYPE html>
<html lang="en">
<head>
    <title>IPython Magic Functions | Kaggle</title>
    <meta charset="utf-8" />
    <meta name="robots" content="index, follow" />
    <meta name="description" content="Explore and run machine learning code with Kaggle Notebooks | Using data from no data sources" />
    <meta name="turbolinks-cache-control" content="no-cache" />
        <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0">
    <meta name="theme-color" content="#008ABC" />
    <script nonce="FiZWW0tnkRJsYlEhXDf4sA==" type="text/javascript">
        if ('serviceWorker' in navigator) {
            navigator.serviceWorker.getRegistrations()
                .then(function(registrations) {
                    for (let registration of registrations) {
                        registration.unregister();
                    }
                })
                .catch(function(err) {
                    console.error("Service worker unregister failed: ", err);
                });
        }
    </script>
    <script nonce="FiZWW0tnkRJsYlEhXDf4sA==" type="text/javascript">
        window["pageRequestStartTime"] = 1616281131028;
        window["pageRequestEndTime"] = 1616281131138;
        window["initialPageLoadStartTime"] = new Date().getTime();
    </script>
    <link rel="preconnect" href="https://www.google-analytics.com" crossorigin="anonymous" /><link rel="preconnect" href="https://stats.g.doubleclick.net" /><link rel="preconnect" href="https://storage.googleapis.com" /><link rel="preconnect" href="https://apis.google.com" />
    <link href="/static/images/favicon.ico" rel="shortcut icon" type="image/x-icon" />
    <link rel="manifest" href="/static/json/manifest.json" crossorigin="use-credentials">
    <link href="//fonts.googleapis.com/css?family=Open+Sans:400,300,300italic,400italic,600,600italic,700,700italic" rel='stylesheet' type='text/css'>
    <link href="https://fonts.googleapis.com/icon?family=Google+Material+Icons" rel="stylesheet" type='text/css' />
        <link rel="canonical" href="/morrisb/ipython-magic-functions" />
        <link rel="stylesheet" type="text/css" href="/static/assets/vendor.css?v=34d7e412fe45d34de18c" />
        <link rel="stylesheet" type="text/css" href="/static/assets/app.css?v=d7a73971c2ad857c2e5d" />
    
    
 
    
    <script nonce="FiZWW0tnkRJsYlEhXDf4sA==">
        try{(function(a,s,y,n,c,h,i,d,e){d=s.createElement("style");
        d.appendChild(s.createTextNode(""));s.head.appendChild(d);d=d.sheet;
        y=y.map(x => d.insertRule(x + "{ opacity: 0 !important }"));
        h.start=1*new Date;h.end=i=function(){y.forEach(x => x<d.cssRules.length ? d.deleteRule(x) : {})};
        (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
        })(window,document,['.site-header-react__nav'],'dataLayer',2000,{'GTM-52LNT9S':true});}catch(ex){}
    </script>
    <script nonce="FiZWW0tnkRJsYlEhXDf4sA==">
        window.dataLayer = window.dataLayer || [];
        function gtag() { dataLayer.push(arguments); }
        gtag('js', new Date());
        gtag('config', 'UA-12629138-1', {
            'optimize_id': 'GTM-52LNT9S',
            'displayFeaturesTask': null,
            'send_page_view': false,
            'content_group1': 'Notebooks'
        });
    </script>
    <script nonce="FiZWW0tnkRJsYlEhXDf4sA==" async src="https://www.googletagmanager.com/gtag/js?id=UA-12629138-1"></script>

    
    
    <meta name="og:url" content="https://kaggle.com/morrisb/ipython-magic-functions" />
    <meta property="og:title" content="IPython Magic Functions" />
    <meta property="og:description" content="Explore and run machine learning code with Kaggle Notebooks | Using data from no data sources" />
    <meta property="og:type" content="website" />
    <meta name="og:image" content="https://storage.googleapis.com/kaggle-avatars/thumbnails/801251-kg.png" />
    
    <meta name="twitter:card" content="summary" />
    <meta name="twitter:site" content="@kaggledatasets" />


    
    
    <script nonce="FiZWW0tnkRJsYlEhXDf4sA==" type="application/ld+json">{"@context":"http://schema.org/","@type":"Article","author":{"@type":"Person","name":"morrisb","sameAs":"/morrisb"},"headline":"IPython Magic Functions","url":"https://www.kaggle.com/morrisb/ipython-magic-functions","dateModified":"2018-07-20T13:58:25.9333333","datePublished":"2018-07-20T13:58:25.9333333","mainEntityOfPage":{"@type":"WebPage","@id":"https://www.kaggle.com/morrisb/ipython-magic-functions"},"publisher":{"@type":"Organization","name":"Kaggle","sameAs":"https://www.kaggle.com","logo":{"type":"ImageObject","url":"https://www.kaggle.com/static/images/site-logo.png"}},"image":["https://storage.googleapis.com/kaggle-avatars/thumbnails/801251-kg.png"]}</script>


    
    
    
<script nonce="FiZWW0tnkRJsYlEhXDf4sA==" type="text/javascript">
    var Kaggle = window.Kaggle || {};

    Kaggle.Current = {
        antiForgeryToken: 'CfDJ8LdUzqlsSWBPr4Ce3rb9VL-OMFsombedWAIFcLLy2ftiHKp4qkxZoOESonvgEklklT_Y0uaWzldW-OmbXeyGLCY9dgX58CMxjlmVDsJOR6gzsl-VsehfJYIkVU4eZ1RC3IcMsanqZHAtxhV8fzdzwbo',
        isAnonymous: true,
        analyticsToken: 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE2MTYyODIwMzEsIlVzZXJJZCI6MH0.QAYZrbI94_JzlyYiLqKhuaHFFfwWd-IQ4v13mhskpEg',
        analyticsTokenExpiry: 15,
        
        
        
        
        
        
        mdeImageUploader: true,
        
        enableRapidash: true, 
    }
        Kaggle.Current.log = function(){};
        Kaggle.Current.warn = function(){};

    var decodeUserDisplayName = function () {
        var escapedUserDisplayName = Kaggle.Current.userDisplayNameEscaped || "";
        try {
            var textVersion = new DOMParser().parseFromString(escapedUserDisplayName, "text/html").documentElement.textContent;
            if (textVersion) {
                return textVersion;
            }
        } catch(ex) {}
        return escapedUserDisplayName;
    }
    Kaggle.Current.userDisplayName = decodeUserDisplayName();
</script>

    

<script nonce="FiZWW0tnkRJsYlEhXDf4sA==" type="text/javascript">
    var Kaggle = window.Kaggle || {};
    Kaggle.PageMessages = [];
</script>

        <script nonce="FiZWW0tnkRJsYlEhXDf4sA==" type="text/javascript">
/* <![CDATA[ */
goog_snippet_vars = function() {
    var w = window;
    w.google_conversion_id = 955616553;
    w.google_conversion_label = "QSjvCKDksHMQqZrWxwM";
    w.google_conversion_value = 0.00;
    w.google_conversion_currency = "USD";
    w.google_remarketing_only = false;
    w.google_conversion_language = "en";
    w.google_conversion_format = "3";
    w.google_conversion_color = "ffffff";
}
// DO NOT CHANGE THE CODE BELOW.
goog_report_conversion = function(url) {
    goog_snippet_vars();
    window.google_conversion_format = "3";
    var opt = new Object();
    opt.onload_callback = function() {
        if (typeof(url) != 'undefined') {
            window.location = url;
        }
    }
    var conv_handler = window['google_trackConversion'];
    if (typeof(conv_handler) == 'function') {
        conv_handler(opt);
    }
}
/* ]]> */
    </script>
    <script nonce="FiZWW0tnkRJsYlEhXDf4sA==" type="text/javascript"
            src="//www.googleadservices.com/pagead/conversion_async.js">
    </script>



        <script nonce="FiZWW0tnkRJsYlEhXDf4sA==">window['useKaggleAnalytics'] = true;</script>

    <script id="gapi-target" nonce="FiZWW0tnkRJsYlEhXDf4sA==" src="https://apis.google.com/js/api.js" defer async></script>
    <script nonce="FiZWW0tnkRJsYlEhXDf4sA==" src="/static/assets/runtime.js?v=bcfd938f60dcaa96208d" data-turbolinks-track="reload"></script>
    <script nonce="FiZWW0tnkRJsYlEhXDf4sA==" src="/static/assets/vendor.js?v=7b78c77114f73a2426d3" data-turbolinks-track="reload"></script>
    <script nonce="FiZWW0tnkRJsYlEhXDf4sA==" src="/static/assets/app.js?v=39b5a9e3317c994fdce0" data-turbolinks-track="reload"></script>
        <script nonce="FiZWW0tnkRJsYlEhXDf4sA==" type="text/javascript">
            window.kaggleStackdriverConfig = {
                key: 'AIzaSyDANGXFHtSIVc51MIdGwg4mQFgm3oNrKoo',
                projectId: 'kaggle-161607',
                service: 'web-fe',
                version: 'ci',
                context: {
                    user: '0',
                },
            };
        </script>
</head>
<body data-turbolinks="false">
    <main>
        






<div id="site-container"></div>
<div data-component-name="NavigationContainer" style="display: flex; flex-direction: column; flex: 1 0 auto;"></div><script class="kaggle-component" nonce="FiZWW0tnkRJsYlEhXDf4sA==">var Kaggle=window.Kaggle||{};Kaggle.State=Kaggle.State||[];Kaggle.State.push({"navigationType":"BOTH_NAV"});performance && performance.mark && performance.mark("NavigationContainer.componentCouldBootstrap");</script>
<div id="site-body" class="hide">
    



<div data-component-name="KernelViewer" style="display: flex; flex-direction: column; flex: 1 0 auto;"></div><script class="kaggle-component" nonce="FiZWW0tnkRJsYlEhXDf4sA==">var Kaggle=window.Kaggle||{};Kaggle.State=Kaggle.State||[];Kaggle.State.push({"kernel":{"id":1300665,"title":"IPython Magic Functions","forkParent":null,"currentRunId":4659544,"mostRecentRunId":4659544,"url":"/morrisb/ipython-magic-functions","tags":[{"name":"advanced","slug":"advanced","url":"/tags/advanced"}],"commentCount":0,"upvoteCount":22,"viewCount":3444,"forkCount":16,"bestPublicScore":null,"author":{"id":801251,"displayName":"Data Liftoff","email":null,"editedEmail":null,"editedEmailCode":null,"userName":"morrisb","thumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/801251-kg.png","profileUrl":"/morrisb","registerDate":"0001-01-01T00:00:00Z","lastVisitDate":"0001-01-01T00:00:00Z","statusId":0,"performanceTier":2,"userLogins":null,"groupIds":null,"duplicateUsers":null,"hasPhoneVerifications":false,"failedNerdchas":0,"hasPendingNerdcha":false,"deleteRequests":null,"isAdmin":false,"isKaggleBot":false,"isAnonymous":false,"canAct":false,"canBeSeen":false,"thumbnailName":null,"isPhoneVerified":false},"isPrivate":false,"updatedTime":"2018-07-20T13:58:25.9333333Z","selfLink":"/kernels/1300665","pinnedDockerImageVersionId":null,"dockerImagePinningType":"original","originalDockerImageId":null,"isLanguageTemplate":false,"medal":"bronze","topicId":61275,"readGroupId":null,"writeGroupId":null,"slug":"ipython-magic-functions","hasUsedAccelerator":null,"pinnedSessionId":null,"disableComments":false,"hasLinkedSubmission":false},"kernelBlob":{"id":29103679,"settings":{"dockerImageVersionId":null,"dataSources":[],"sourceType":"notebook","language":"python","accelerator":"none","isInternetEnabled":false},"source":"{\u0022cells\u0022:[{\u0022metadata\u0022:{\u0022_uuid\u0022:\u00228f2839f25d086af736a60e9eeb907d3b93b6e0e5\u0022,\u0022_cell_guid\u0022:\u0022b1076dfc-b9ad-4769-8c92-a6c4dae69d19\u0022,\u0022trusted\u0022:true,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022markdown\u0022,\u0022source\u0022:\u0022# IPython Magic Functions \\n\\n**Built-in magic functions** can support your programming **in Kaggle-Kernels and IPython Notebooks.**    \\nYou can use those functions to **optimize your run-time, to combine different programming languages** in a single notebook or to **execute bash-scripts.**\\n\\n - Lines starting with an **\u0027%\u0027** will be interpreted as magic function.    \\n - A single **\u0027%\u0027** will only evaluate the attached **line of code.**    \\n - A double **\u0027%%\u0027** will operate on the **whole notebook-cell.**    \\n\\n**P.S:**   \\nSince **some outputs cannot be saved in a kernel**, fork this notebook and run the cells on your own to see all outputs.\\n\\n## Which Functions Are Available? \u0022},{\u0022metadata\u0022:{\u0022_cell_guid\u0022:\u002279c7e3d0-c299-4dcb-8224-4455121ee9b0\u0022,\u0022_uuid\u0022:\u0022d629ff2d2480ee46fbb7e2d37f6b5fab8052498a\u0022,\u0022trusted\u0022:true,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%lsmagic\\n# You can add more on your local machine \u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022_uuid\u0022:\u0022e8aab2532b8f62be3a045068744b9b2453fdbf83\u0022},\u0022cell_type\u0022:\u0022markdown\u0022,\u0022source\u0022:\u0022## How To Get The Function Description? \u0022},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022collapsed\u0022:true,\u0022_uuid\u0022:\u0022fba1eadd9ac530d9befa1aff385327b4d9d69ce0\u0022},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%lsmagic?\\n# Use a questionmark to get a short description \u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022_uuid\u0022:\u0022ff318125e5f84ca5bc1c8be5319c858c7c862702\u0022},\u0022cell_type\u0022:\u0022markdown\u0022,\u0022source\u0022:\u0022## How To Quantify Execution Time? \u0022},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022334053bc0d85244e0761572c87a015ee98da9b89\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Get random numbers to measure sorting time \\nimport numpy as np\\nn = 100000\\nrandom_numbers = np.random.random(size=n)\\n\\n%time random_numbers_sorted = np.sort(random_numbers)\\n# Get execution time of a single line \u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022c4c4c985cd86b38b45947be495057dd047be8d5e\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%%time\\n# Get execution time of a whole cell (Has to be the first command in the cell) \\n\\nrandom_numbers = np.random.random(size=n)\\nrandom_numbers_sorted = np.sort(random_numbers)\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022_uuid\u0022:\u00229bba68c39cd210fb74c34a2bb1f6d9d4c75ec3fe\u0022},\u0022cell_type\u0022:\u0022markdown\u0022,\u0022source\u0022:\u0022Measuring a short statement onetime can be inaccurate.\u003cbr\u003e\\nThat is why the **\u0027%timeit\u0027** function executes the statement several times and returns a summary of all durations.\u0022},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022415936e611b26a2a92525822791190f94e0a4618\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%timeit -n 100 -r 5 random_numbers_sorted = np.sort(random_numbers)\\n# n - execute the statement n times \\n# r - repeat each loop r times and return the best \u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022ee1efb5a31b9c7379c34f86e16abebe8bb2e214e\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%%timeit -n 100 -r 5\\n# n - execute the statement n times \\n# r - repeat each loop r times and return the best \\n\\nrandom_numbers = np.random.random(size=n)\\nrandom_numbers_sorted = np.sort(random_numbers)\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022_uuid\u0022:\u0022a39da405b19b4aae6b4b83f25ce66a3f9a1330a4\u0022},\u0022cell_type\u0022:\u0022markdown\u0022,\u0022source\u0022:\u0022## How To Measure The Time Of Each Function In A Cell? \u0022},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022476bec53e4aa3886f15db91cfc95c1067525cb8b\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%%prun\\n# Returns a duration ranking of all called functions in the cell as well as a count for all funcition calls (Can only be seen by running it on your own) \\n\\nfor _ in range(5):\\n    random_numbers = np.random.random(size=n)\\n    random_numbers_sorted = np.sort(random_numbers)\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022_uuid\u0022:\u002277e08277f90738020dee4ee21394a455c5c79c91\u0022},\u0022cell_type\u0022:\u0022markdown\u0022,\u0022source\u0022:\u0022The output can be a little bit cryptic. Therefore using the **%lprun** ([Install separatly](http://pynash.org/2013/03/06/timing-and-profiling/)) can be more helpful since it measures the execution-time for each line in the cell. \\n\\n## How To Measure Memory Usage In A Cell? \\n\\nUse **%mprun** (Memory line-by-line in a function)  and **%memit** (Memory iteratively several times) just as the previous example.  ([Install separatly](http://pynash.org/2013/03/06/timing-and-profiling/))\\n\\n## How To Execute Bash Commands? \\n\\nHere are a few standard bash commands to use them right in the cells.\u0022},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022b7a7876a7f8da970a27cfad6011490dde32577d7\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Return working directory \\n%pwd\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u002253037dd1a938c34846afca7a6b054e492a0fb68b\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Create a new folder \\n%mkdir \u0027test_folder\u0027\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022644a89b043c48efaf920b4e50b8643711dda0bfe\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Save to new .py file \\ntext = \u0027I am going into a new file\u0027\\n%save \u0027new_file\u0027 text\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022collapsed\u0022:true,\u0022_uuid\u0022:\u0022a096fa0e94e8af590656058bce5ae46b6aa8140a\u0022},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Copy files to a new location \\n%cp new_file.py new_file_2.py\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022a0d58b36bcae7138bdbaf4daf0bb39d0f6d61de4\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# List of elements in current directory \\n%ls\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u002242ba4ea06ff2ce4231806ba5f054c79ba72e1968\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Read7show files \\n%cat new_file.py\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022collapsed\u0022:true,\u0022_uuid\u0022:\u0022e4cf59cc72e4749f79a0e51cd6619767dd48821b\u0022},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Remove folder \\n%rmdir test_folder/\\n\\n# Remove files \\n%rm new_file.py\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022collapsed\u0022:true,\u0022_uuid\u0022:\u0022fafc470ae033aa7a052b0f365ac0a10af33e909d\u0022},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Rename files \\n%mv new_file_2.py renamed_file.py\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u002213734cfecdfd69f89a9b3a2cd9ee3ff6bb707a2e\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%ls\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022d32c249c2f2ca64408fc2bb9827344d358669a0d\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Using a \u0027!\u0027 neables arbitrary single-line bash-commands \\n!ls | grep .py\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u00222e1af2167c133384f9e829f0350f3bdb0c9994da\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%%!\\n# This executes the whole cell in a bash and returns a list \\npwd\\nls\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022426aa309dbb6c8d61e05039ed8fdea653f9bb258\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%%bash\\n# This executes the whole cell in a bash and returns single elements \\npwd\\nls\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u00221550b1fb311aef91c756bcc2f008b835354a28f7\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# The returned values can be stored in variables \\nworking_directory = !pwd\\nworking_directory\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022_uuid\u0022:\u0022a276e82493a1b111616bd37a3fb077e277ca39cd\u0022},\u0022cell_type\u0022:\u0022markdown\u0022,\u0022source\u0022:\u0022## How To Style Your Notebooks? \u0022},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022collapsed\u0022:true,\u0022_uuid\u0022:\u00220a90efe03db20285f98dc579743fb75a8f755bf2\u0022},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Compile latex in cells \u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u002202bb792c1485538c4190ed24e6c8bcdd551365e6\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%%latex\\n$\\\\frac{awe}{some}$\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022collapsed\u0022:true,\u0022_uuid\u0022:\u0022f9eb0d2dd45de32975840f335447bda34ba7c2c4\u0022},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Html in cells \u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u002285422f5b1a1f4c4e1212e21fd6a7da8c0702c409\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%%HTML\\n\\n\u003ch1\u003eAwesome\u003c/h1\u003e\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022_uuid\u0022:\u0022eccb887255d2a3f67c0c98b997990b9979379005\u0022},\u0022cell_type\u0022:\u0022markdown\u0022,\u0022source\u0022:\u0022## How To Use Different Programming Languages? \u0022},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u00221ff6ae090b49638e41d43f5af1e942ed5b9b89f5\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%%javascript\\n\\nwindow.alert(\u0027Here you can learn how to use magic functions inside notebooks.\\\\nHave a good day!\u0027)\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022collapsed\u0022:true,\u0022_uuid\u0022:\u002212887d2243f383e97f0a444ef6fb5a91c7dcbe8c\u0022},\u0022cell_type\u0022:\u0022markdown\u0022,\u0022source\u0022:\u0022## More Tutorials \\nA few more tipps can be found here:    \\n[Timing and Profiling in IPython](http://pynash.org/2013/03/06/timing-and-profiling/)    \\n[Advanced Jupyter Notebook](https://blog.dominodatalab.com/lesser-known-ways-of-using-notebooks/)    \\n[Make Jupyter/IPython Notebook even more magical with cell magic extensions!](https://www.youtube.com/watch?v=zxkdO07L29Q)\\n\\n**Have a good day!**\u0022},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022collapsed\u0022:true,\u0022_uuid\u0022:\u0022b2a9ba7199162773794d102a1d8173774be30468\u0022},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]}],\u0022metadata\u0022:{\u0022kernelspec\u0022:{\u0022display_name\u0022:\u0022Python 3\u0022,\u0022language\u0022:\u0022python\u0022,\u0022name\u0022:\u0022python3\u0022},\u0022language_info\u0022:{\u0022name\u0022:\u0022python\u0022,\u0022version\u0022:\u00223.6.6\u0022,\u0022mimetype\u0022:\u0022text/x-python\u0022,\u0022codemirror_mode\u0022:{\u0022name\u0022:\u0022ipython\u0022,\u0022version\u0022:3},\u0022pygments_lexer\u0022:\u0022ipython3\u0022,\u0022nbconvert_exporter\u0022:\u0022python\u0022,\u0022file_extension\u0022:\u0022.py\u0022}},\u0022nbformat\u0022:4,\u0022nbformat_minor\u0022:1}","dateCreated":"2018-07-20T13:58:25.3702155Z"},"kernelRun":{"id":4659544,"kernelId":1300665,"status":"complete","type":"batch","sourceType":"notebook","language":"python","title":"IPython Magic Functions","dateCreated":"2018-07-20T13:58:25.463Z","dateEvaluated":"2018-07-20T13:58:25.933Z","dateCancelled":null,"workerContainerPort":null,"workerUptimeSeconds":1774227,"workerIPAddress":"172.16.8.11    ","workerIPAddressExternal":null,"scriptLanguageId":9,"scriptLanguageName":"IPython Notebook HTML","renderedOutputUrl":"https://www.kaggleusercontent.com/kf/4659544/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2In0..wlK4Qw8LxEcPwhuj-j-MDg.lYGFN5_1cZrox7Ypoa_qKsY9bH-2aPmoKp4RgYr3XlNqfYsujPZTg_fJkPxRkWmaAcjDSoUv20z2k71ailM46A3dcnt_Rk21yVqv39ub08T8og3pvDKNzA4r2hmyMWbrNoLUrdPDZV6Zl0btD-ReWA6ld3mz5jhXNo1OlUYNIs9xcmSaL2UTO5QfyaXWFqOTb0rdD-ASS-Lgbq_1Fm7NkEaFhI-UKCZqsx3HZ6vt-Z9Q04_ZKIx-y49WmZ-wCJYc4NaI73whExKcoJWnqTeRtrLjRyxgS17oFmrLKyDtPOl6wku6Nzu_I3TeD7qG3vWQeLFU5DUqhnymI-KNXLAUFFZ6x6B21Xxd5FkkO6wTYpU7wLdGMDTgOANIl8l94QXjhyLChDgHNXOo2cJmCwJDCdQO8ZeOxwlLXlkM6s9Buv7rj_LVxV6_Y68EwAvmICDt6oxy5N-jMy3pkEaWhaczqQRR4MHd7aq3Bls9SrzD1vf40WMLnoT5RLnQJKk3d-T_I4EbyErCh8D-7KfBjyt9m_Sc9Adl7vMnkpQaxsGXUlYMClnjUHEl2K5wYEKjRWLsc0LZdpMspSohTy-u1RHZxW0mK8lsADpzkiS0HH-eWgi0kzvnLDX1FrFZY4Ci1YgSUPqPzufWPiU7Kv1t1QO9sD0z1mWFr1cvY5gEMLd2bxA.8RkuoldhlFq_VUNHRHfQCg/__results__.html","commit":{"id":29103679,"settings":{"dockerImageVersionId":null,"dataSources":[],"sourceType":"notebook","language":"python","accelerator":"none","isInternetEnabled":false},"source":"{\u0022cells\u0022:[{\u0022metadata\u0022:{\u0022_uuid\u0022:\u00228f2839f25d086af736a60e9eeb907d3b93b6e0e5\u0022,\u0022_cell_guid\u0022:\u0022b1076dfc-b9ad-4769-8c92-a6c4dae69d19\u0022,\u0022trusted\u0022:true,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022markdown\u0022,\u0022source\u0022:\u0022# IPython Magic Functions \\n\\n**Built-in magic functions** can support your programming **in Kaggle-Kernels and IPython Notebooks.**    \\nYou can use those functions to **optimize your run-time, to combine different programming languages** in a single notebook or to **execute bash-scripts.**\\n\\n - Lines starting with an **\u0027%\u0027** will be interpreted as magic function.    \\n - A single **\u0027%\u0027** will only evaluate the attached **line of code.**    \\n - A double **\u0027%%\u0027** will operate on the **whole notebook-cell.**    \\n\\n**P.S:**   \\nSince **some outputs cannot be saved in a kernel**, fork this notebook and run the cells on your own to see all outputs.\\n\\n## Which Functions Are Available? \u0022},{\u0022metadata\u0022:{\u0022_cell_guid\u0022:\u002279c7e3d0-c299-4dcb-8224-4455121ee9b0\u0022,\u0022_uuid\u0022:\u0022d629ff2d2480ee46fbb7e2d37f6b5fab8052498a\u0022,\u0022trusted\u0022:true,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%lsmagic\\n# You can add more on your local machine \u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022_uuid\u0022:\u0022e8aab2532b8f62be3a045068744b9b2453fdbf83\u0022},\u0022cell_type\u0022:\u0022markdown\u0022,\u0022source\u0022:\u0022## How To Get The Function Description? \u0022},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022collapsed\u0022:true,\u0022_uuid\u0022:\u0022fba1eadd9ac530d9befa1aff385327b4d9d69ce0\u0022},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%lsmagic?\\n# Use a questionmark to get a short description \u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022_uuid\u0022:\u0022ff318125e5f84ca5bc1c8be5319c858c7c862702\u0022},\u0022cell_type\u0022:\u0022markdown\u0022,\u0022source\u0022:\u0022## How To Quantify Execution Time? \u0022},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022334053bc0d85244e0761572c87a015ee98da9b89\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Get random numbers to measure sorting time \\nimport numpy as np\\nn = 100000\\nrandom_numbers = np.random.random(size=n)\\n\\n%time random_numbers_sorted = np.sort(random_numbers)\\n# Get execution time of a single line \u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022c4c4c985cd86b38b45947be495057dd047be8d5e\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%%time\\n# Get execution time of a whole cell (Has to be the first command in the cell) \\n\\nrandom_numbers = np.random.random(size=n)\\nrandom_numbers_sorted = np.sort(random_numbers)\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022_uuid\u0022:\u00229bba68c39cd210fb74c34a2bb1f6d9d4c75ec3fe\u0022},\u0022cell_type\u0022:\u0022markdown\u0022,\u0022source\u0022:\u0022Measuring a short statement onetime can be inaccurate.\u003cbr\u003e\\nThat is why the **\u0027%timeit\u0027** function executes the statement several times and returns a summary of all durations.\u0022},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022415936e611b26a2a92525822791190f94e0a4618\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%timeit -n 100 -r 5 random_numbers_sorted = np.sort(random_numbers)\\n# n - execute the statement n times \\n# r - repeat each loop r times and return the best \u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022ee1efb5a31b9c7379c34f86e16abebe8bb2e214e\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%%timeit -n 100 -r 5\\n# n - execute the statement n times \\n# r - repeat each loop r times and return the best \\n\\nrandom_numbers = np.random.random(size=n)\\nrandom_numbers_sorted = np.sort(random_numbers)\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022_uuid\u0022:\u0022a39da405b19b4aae6b4b83f25ce66a3f9a1330a4\u0022},\u0022cell_type\u0022:\u0022markdown\u0022,\u0022source\u0022:\u0022## How To Measure The Time Of Each Function In A Cell? \u0022},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022476bec53e4aa3886f15db91cfc95c1067525cb8b\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%%prun\\n# Returns a duration ranking of all called functions in the cell as well as a count for all funcition calls (Can only be seen by running it on your own) \\n\\nfor _ in range(5):\\n    random_numbers = np.random.random(size=n)\\n    random_numbers_sorted = np.sort(random_numbers)\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022_uuid\u0022:\u002277e08277f90738020dee4ee21394a455c5c79c91\u0022},\u0022cell_type\u0022:\u0022markdown\u0022,\u0022source\u0022:\u0022The output can be a little bit cryptic. Therefore using the **%lprun** ([Install separatly](http://pynash.org/2013/03/06/timing-and-profiling/)) can be more helpful since it measures the execution-time for each line in the cell. \\n\\n## How To Measure Memory Usage In A Cell? \\n\\nUse **%mprun** (Memory line-by-line in a function)  and **%memit** (Memory iteratively several times) just as the previous example.  ([Install separatly](http://pynash.org/2013/03/06/timing-and-profiling/))\\n\\n## How To Execute Bash Commands? \\n\\nHere are a few standard bash commands to use them right in the cells.\u0022},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022b7a7876a7f8da970a27cfad6011490dde32577d7\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Return working directory \\n%pwd\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u002253037dd1a938c34846afca7a6b054e492a0fb68b\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Create a new folder \\n%mkdir \u0027test_folder\u0027\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022644a89b043c48efaf920b4e50b8643711dda0bfe\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Save to new .py file \\ntext = \u0027I am going into a new file\u0027\\n%save \u0027new_file\u0027 text\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022collapsed\u0022:true,\u0022_uuid\u0022:\u0022a096fa0e94e8af590656058bce5ae46b6aa8140a\u0022},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Copy files to a new location \\n%cp new_file.py new_file_2.py\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022a0d58b36bcae7138bdbaf4daf0bb39d0f6d61de4\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# List of elements in current directory \\n%ls\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u002242ba4ea06ff2ce4231806ba5f054c79ba72e1968\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Read7show files \\n%cat new_file.py\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022collapsed\u0022:true,\u0022_uuid\u0022:\u0022e4cf59cc72e4749f79a0e51cd6619767dd48821b\u0022},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Remove folder \\n%rmdir test_folder/\\n\\n# Remove files \\n%rm new_file.py\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022collapsed\u0022:true,\u0022_uuid\u0022:\u0022fafc470ae033aa7a052b0f365ac0a10af33e909d\u0022},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Rename files \\n%mv new_file_2.py renamed_file.py\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u002213734cfecdfd69f89a9b3a2cd9ee3ff6bb707a2e\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%ls\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022d32c249c2f2ca64408fc2bb9827344d358669a0d\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Using a \u0027!\u0027 neables arbitrary single-line bash-commands \\n!ls | grep .py\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u00222e1af2167c133384f9e829f0350f3bdb0c9994da\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%%!\\n# This executes the whole cell in a bash and returns a list \\npwd\\nls\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u0022426aa309dbb6c8d61e05039ed8fdea653f9bb258\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%%bash\\n# This executes the whole cell in a bash and returns single elements \\npwd\\nls\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u00221550b1fb311aef91c756bcc2f008b835354a28f7\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# The returned values can be stored in variables \\nworking_directory = !pwd\\nworking_directory\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022_uuid\u0022:\u0022a276e82493a1b111616bd37a3fb077e277ca39cd\u0022},\u0022cell_type\u0022:\u0022markdown\u0022,\u0022source\u0022:\u0022## How To Style Your Notebooks? \u0022},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022collapsed\u0022:true,\u0022_uuid\u0022:\u00220a90efe03db20285f98dc579743fb75a8f755bf2\u0022},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Compile latex in cells \u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u002202bb792c1485538c4190ed24e6c8bcdd551365e6\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%%latex\\n$\\\\frac{awe}{some}$\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022collapsed\u0022:true,\u0022_uuid\u0022:\u0022f9eb0d2dd45de32975840f335447bda34ba7c2c4\u0022},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022# Html in cells \u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u002285422f5b1a1f4c4e1212e21fd6a7da8c0702c409\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%%HTML\\n\\n\u003ch1\u003eAwesome\u003c/h1\u003e\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022_uuid\u0022:\u0022eccb887255d2a3f67c0c98b997990b9979379005\u0022},\u0022cell_type\u0022:\u0022markdown\u0022,\u0022source\u0022:\u0022## How To Use Different Programming Languages? \u0022},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022_uuid\u0022:\u00221ff6ae090b49638e41d43f5af1e942ed5b9b89f5\u0022,\u0022collapsed\u0022:true},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022%%javascript\\n\\nwindow.alert(\u0027Here you can learn how to use magic functions inside notebooks.\\\\nHave a good day!\u0027)\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022collapsed\u0022:true,\u0022_uuid\u0022:\u002212887d2243f383e97f0a444ef6fb5a91c7dcbe8c\u0022},\u0022cell_type\u0022:\u0022markdown\u0022,\u0022source\u0022:\u0022## More Tutorials \\nA few more tipps can be found here:    \\n[Timing and Profiling in IPython](http://pynash.org/2013/03/06/timing-and-profiling/)    \\n[Advanced Jupyter Notebook](https://blog.dominodatalab.com/lesser-known-ways-of-using-notebooks/)    \\n[Make Jupyter/IPython Notebook even more magical with cell magic extensions!](https://www.youtube.com/watch?v=zxkdO07L29Q)\\n\\n**Have a good day!**\u0022},{\u0022metadata\u0022:{\u0022trusted\u0022:true,\u0022collapsed\u0022:true,\u0022_uuid\u0022:\u0022b2a9ba7199162773794d102a1d8173774be30468\u0022},\u0022cell_type\u0022:\u0022code\u0022,\u0022source\u0022:\u0022\u0022,\u0022execution_count\u0022:null,\u0022outputs\u0022:[]}],\u0022metadata\u0022:{\u0022kernelspec\u0022:{\u0022display_name\u0022:\u0022Python 3\u0022,\u0022language\u0022:\u0022python\u0022,\u0022name\u0022:\u0022python3\u0022},\u0022language_info\u0022:{\u0022name\u0022:\u0022python\u0022,\u0022version\u0022:\u00223.6.6\u0022,\u0022mimetype\u0022:\u0022text/x-python\u0022,\u0022codemirror_mode\u0022:{\u0022name\u0022:\u0022ipython\u0022,\u0022version\u0022:3},\u0022pygments_lexer\u0022:\u0022ipython3\u0022,\u0022nbconvert_exporter\u0022:\u0022python\u0022,\u0022file_extension\u0022:\u0022.py\u0022}},\u0022nbformat\u0022:4,\u0022nbformat_minor\u0022:1}","dateCreated":"2018-07-20T13:58:25.3702155Z"},"resources":null,"isolatorResults":"\u003cresults\u003e\u003cdisk_kb_free\u003e945032\u003c/disk_kb_free\u003e\u003cdocker_image_digest\u003e93d8dca0dec26d400c75e69c7177f4fae209d6d1971286b5bd7a75511d23c67e\u003c/docker_image_digest\u003e\u003cdocker_image_id\u003esha256:2c55b963ef053af507ef1a7ae583013b31fae6bed350fb903e436304c3540660\u003c/docker_image_id\u003e\u003cdocker_image_name\u003egcr.io/kaggle-images/python\u003c/docker_image_name\u003e\u003cexit_code\u003e0\u003c/exit_code\u003e\u003cfailure_message /\u003e\u003cinvalid_path_errors\u003eFalse\u003c/invalid_path_errors\u003e\u003cout_of_memory\u003eFalse\u003c/out_of_memory\u003e\u003crun_time_seconds\u003e26.5894732221495\u003c/run_time_seconds\u003e\u003csucceeded\u003eTrue\u003c/succeeded\u003e\u003ctimeout_exceeded\u003eFalse\u003c/timeout_exceeded\u003e\u003cused_all_space\u003eFalse\u003c/used_all_space\u003e\u003cwas_killed\u003eFalse\u003c/was_killed\u003e\u003c/results\u003e","runInfo":{"dockerfileUrl":"https://github.com/Kaggle/docker-python/blob/master/Dockerfile","dockerHubUrl":"https://gcr.io/kaggle-images/python","dockerImageDigest":"93d8dca0dec26d400c75e69c7177f4fae209d6d1971286b5bd7a75511d23c67e","dockerImageId":"sha256:2c55b963ef053af507ef1a7ae583013b31fae6bed350fb903e436304c3540660","dockerImageName":"gcr.io/kaggle-images/python","diskKbFree":945032,"failureMessage":"","exitCode":0,"queuedSeconds":0,"outputSizeBytes":0,"runTimeSeconds":26.5894732221495,"usedAllSpace":false,"timeoutExceeded":false,"isValidStatus":false,"wasGpuEnabled":false,"wasInternetEnabled":false,"outOfMemory":false,"invalidPathErrors":false,"succeeded":true,"wasKilled":false},"dockerImageVersionId":5671,"usedCustomDockerImage":false,"dataSources":[],"useNewKernelsBackend":null,"isGpuEnabled":false,"isTpuEnabled":false,"acceleratorType":"none","isInternetEnabled":false,"userPlan":"free"},"author":{"id":801251,"displayName":"Data Liftoff","email":null,"editedEmail":null,"editedEmailCode":null,"userName":"morrisb","thumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/801251-kg.png","profileUrl":"/morrisb","registerDate":"0001-01-01T00:00:00Z","lastVisitDate":"0001-01-01T00:00:00Z","statusId":0,"performanceTier":2,"userLogins":null,"groupIds":null,"duplicateUsers":null,"hasPhoneVerifications":false,"failedNerdchas":0,"hasPendingNerdcha":false,"deleteRequests":null,"isAdmin":false,"isKaggleBot":false,"isAnonymous":false,"canAct":false,"canBeSeen":false,"thumbnailName":null,"isPhoneVerified":false},"baseUrl":"/morrisb/ipython-magic-functions","collaborators":{"owner":{"userId":801251,"groupId":null,"groupMemberCount":null,"profileUrl":"/morrisb","thumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/801251-kg.png","name":"Data Liftoff","slug":"morrisb","userTier":2,"joinDate":null,"type":"owner","isUser":true,"isGroup":false},"collaborators":[]},"initialTab":null,"log":"[{\n  \u0022data\u0022: \u0022[NbConvertApp] Converting notebook script.ipynb to html\\n\u0022,\n  \u0022stream_name\u0022: \u0022stderr\u0022,\n  \u0022time\u0022: 6.200610741972923\n},{\n  \u0022data\u0022: \u0022[NbConvertApp] Executing notebook with kernel: python3\\n\u0022,\n  \u0022stream_name\u0022: \u0022stderr\u0022,\n  \u0022time\u0022: 6.248354092007503\n},{\n  \u0022data\u0022: \u0022[NbConvertApp] Writing 273310 bytes to __results__.html\\n\u0022,\n  \u0022stream_name\u0022: \u0022stderr\u0022,\n  \u0022time\u0022: 25.558088907040656\n}]","outputFiles":[{"ownerInfo":null,"kernelVersionOutputFileId":13360382,"kernelVersionId":4659544,"kernelId":1300665,"size":0,"fullPath":"renamed_file.py","downloadUrl":"https://www.kaggleusercontent.com/kf/4659544/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2In0..lRF0ctvco5UZSP_thhoOoA.Rdn9A7eOCQVei6qJCvAuyV4_046ppphaXkCb4OO-7nVhmZXept1O0U7DkjS8AT0-V33kIqPgrDLQ6SVRPx8HAxmDB7g0ECtdOoa_bR5eiz9Eq7AR7uopMqCHm_dD1AnBaXg984BanWEOeDMxgwPwNcbmN17m2tontRf9OyQlH3WggTI6rzYvHYy3_NHx-zG2KdF-XxwbaSbnBi6eJPCb5_CVtRDIW87k213LNsCg6q8e6fuUooEmVRfsw7jOq0DtGTbDvHdfl15f-2TxS5V5taOqKqsmrkCV6N2qv0mmun16JohvidUaqhmXf3o5bNErmK_Z_LeAEX5JAWY3PFLDeXFkI36CQUWmcVx-fFLiTH0BBnt7kp9fansXUW-uCX9L_E9fRPHbOpLiRVBAGuhpQ9_OGQdrkbUU_bOtQysUOc-11jnYh83gxQuOBobVMGohdbqfrXn6JH5CyuRmaKdg50Si1Mkc7tjZwaBNtOmBJWcPslNi2D66ye0hq2T8T1fdgCkpmAIEIIHTZh_-ClU1J3HPTpp-y4njSakZ1Q1Yds-9OZ2DP1QpNsJp24wydZCX5r68Ye5W0XrS4MQLtZ4DLaHRW4DT4aO2jTBzPQOV7ZMDXzo1NjUCN-We-tDKS6iavRaDUMah7f3sVHlR9H7dI8qZ4tAPOUXK2wv4ktmwTag.dSpreNOY0sAzOwAVCYk72Q/renamed_file.py","fileType":".py","contentLength":43,"contentType":null,"contentMD5":null,"validationErrors":null,"type":"kernelOutputFile","collapsed":false,"info":{"metrics":null,"archiveInfo":null,"archiveInfoV2":null,"blobFileInfo":null,"convertCsvInfo":null,"kernelReference":null},"settings":{"csvSettings":null,"bigQuerySettings":null,"bigQueryMirrorSettings":null,"storageSettings":null,"remoteUrlSettings":null,"remoteGithubSettings":null},"render":null,"totalChildren":0,"children":[],"firestorePath":null,"firestoreKey":null,"name":"renamed_file.py","description":null}],"outputFilesCropped":false,"ouputFilesOwnerInfo":{"databundleVersionId":0,"dataset":null,"competition":null,"kernel":{"kernelId":1300665,"kernelVersionId":4659544,"scope":"morrisb/ipython-magic-functions"},"previewsDisabled":false},"pageMessages":[],"dataSources":[],"versions":[{"id":4659544,"kernelVersionId":null,"isForkParent":false,"isNotebook":true,"languageName":"Python","lastRunTime":"2018-07-20T13:58:25.463Z","linesChangedFromPrevious":0,"linesDeletedFromPrevious":29,"linesInsertedFromPrevious":29,"outputFilesTotalSizeBytes":0,"runInfo":{"dockerfileUrl":"https://github.com/Kaggle/docker-python/blob/master/Dockerfile","dockerHubUrl":"https://registry.hub.docker.com/u/kaggle/python/","dockerImageId":"sha256:2c55b963ef053af507ef1a7ae583013b31fae6bed350fb903e436304c3540660","dockerImageName":"gcr.io/kaggle-images/python","exitCode":0,"failureMessage":"","isValidStatus":true,"runTimeSeconds":26.5894732221495,"succeeded":true,"timeoutExceeded":false,"usedAllSpace":false},"status":"complete","title":"IPython Magic Functions","url":"/morrisb/ipython-magic-functions?scriptVersionId=4659544","versionNumber":4,"hasVersionNumber":true,"isRedacted":false,"versionAuthor":null,"versionType":"batch","userPlan":"free"},{"id":4612975,"kernelVersionId":null,"isForkParent":false,"isNotebook":true,"languageName":"Python","lastRunTime":"2018-07-17T18:46:04.473Z","linesChangedFromPrevious":0,"linesDeletedFromPrevious":11,"linesInsertedFromPrevious":11,"outputFilesTotalSizeBytes":0,"runInfo":{"dockerfileUrl":"https://github.com/Kaggle/docker-python/blob/master/Dockerfile","dockerHubUrl":"https://registry.hub.docker.com/u/kaggle/python/","dockerImageId":"sha256:2c55b963ef053af507ef1a7ae583013b31fae6bed350fb903e436304c3540660","dockerImageName":"gcr.io/kaggle-images/python","exitCode":0,"failureMessage":"","isValidStatus":true,"runTimeSeconds":25.8519158280687,"succeeded":true,"timeoutExceeded":false,"usedAllSpace":false},"status":"complete","title":"IPython Magic Functions","url":"/morrisb/ipython-magic-functions?scriptVersionId=4612975","versionNumber":3,"hasVersionNumber":true,"isRedacted":false,"versionAuthor":null,"versionType":"batch","userPlan":"free"},{"id":4606620,"kernelVersionId":null,"isForkParent":false,"isNotebook":true,"languageName":"Python","lastRunTime":"2018-07-17T10:33:56.497Z","linesChangedFromPrevious":0,"linesDeletedFromPrevious":13,"linesInsertedFromPrevious":21,"outputFilesTotalSizeBytes":0,"runInfo":{"dockerfileUrl":"https://github.com/Kaggle/docker-python/blob/master/Dockerfile","dockerHubUrl":"https://registry.hub.docker.com/u/kaggle/python/","dockerImageId":"sha256:2c55b963ef053af507ef1a7ae583013b31fae6bed350fb903e436304c3540660","dockerImageName":"gcr.io/kaggle-images/python","exitCode":0,"failureMessage":"","isValidStatus":true,"runTimeSeconds":26.5657630411442,"succeeded":true,"timeoutExceeded":false,"usedAllSpace":false},"status":"complete","title":"IPython Magic Functions","url":"/morrisb/ipython-magic-functions?scriptVersionId=4606620","versionNumber":2,"hasVersionNumber":true,"isRedacted":false,"versionAuthor":null,"versionType":"batch","userPlan":"free"},{"id":4599313,"kernelVersionId":null,"isForkParent":false,"isNotebook":true,"languageName":"Python","lastRunTime":"2018-07-16T23:47:46.647Z","linesChangedFromPrevious":0,"linesDeletedFromPrevious":0,"linesInsertedFromPrevious":138,"outputFilesTotalSizeBytes":0,"runInfo":{"dockerfileUrl":"https://github.com/Kaggle/docker-python/blob/master/Dockerfile","dockerHubUrl":"https://registry.hub.docker.com/u/kaggle/python/","dockerImageId":"sha256:2c55b963ef053af507ef1a7ae583013b31fae6bed350fb903e436304c3540660","dockerImageName":"gcr.io/kaggle-images/python","exitCode":0,"failureMessage":"","isValidStatus":true,"runTimeSeconds":21.9000307160895,"succeeded":true,"timeoutExceeded":false,"usedAllSpace":false},"status":"complete","title":"IPython Magic Functions","url":"/morrisb/ipython-magic-functions?scriptVersionId=4599313","versionNumber":1,"hasVersionNumber":true,"isRedacted":false,"versionAuthor":null,"versionType":"batch","userPlan":"free"}],"categories":{"type":"notebook","tags":[{"id":13104,"name":"advanced","fullPath":"audience \u003e advanced","listingUrl":"/notebooks?sortBy=relevance\u0026group=all\u0026search=tag%3A%27advanced%27","description":null,"datasetCount":72,"competitionCount":0,"notebookCount":196,"tagUrl":"/tags/advanced","displayName":"Advanced","fontAwesomeIcon":""}]},"downloadAllFilesUrl":"/kernels/svzip/4659544","submission":null,"menuLinks":[{"href":"/morrisb/ipython-magic-functions/notebook","text":"Notebook","showOnMobile":true,"title":"Notebook","tab":"notebook","count":null,"showZeroCountExplicitly":false,"reportEventCategory":null,"reportEventType":null},{"href":"/morrisb/ipython-magic-functions/code","text":"Code","showOnMobile":true,"title":"Code","tab":"code","count":null,"showZeroCountExplicitly":false,"reportEventCategory":null,"reportEventType":null},{"href":"/morrisb/ipython-magic-functions/data","text":"Input","showOnMobile":true,"title":"Input","tab":"data","count":0,"showZeroCountExplicitly":false,"reportEventCategory":null,"reportEventType":null},{"href":"/morrisb/ipython-magic-functions/output","text":"Output","showOnMobile":false,"title":"Output","tab":"output","count":null,"showZeroCountExplicitly":false,"reportEventCategory":null,"reportEventType":null},{"href":"/morrisb/ipython-magic-functions/execution","text":"Execution Info","showOnMobile":false,"title":"Execution Info","tab":"execution","count":null,"showZeroCountExplicitly":false,"reportEventCategory":null,"reportEventType":null},{"href":"/morrisb/ipython-magic-functions/log","text":"Log","showOnMobile":false,"title":"Log","tab":"log","count":null,"showZeroCountExplicitly":false,"reportEventCategory":null,"reportEventType":null},{"href":"/morrisb/ipython-magic-functions/comments","text":"Comments","showOnMobile":true,"title":"Comments","tab":"comments","count":10,"showZeroCountExplicitly":true,"reportEventCategory":null,"reportEventType":null}],"rightMenuLinks":[],"callToAction":{"href":"/code/fork-version/4659544","text":"Fork Notebook","showOnMobile":true,"title":"Fork Notebook","tab":null,"count":null,"showZeroCountExplicitly":false,"reportEventCategory":"kernels","reportEventType":"anonymousKernelForkCreation"},"voteButton":{"totalVotes":22,"medalVotes":16,"hasAlreadyVotedUp":false,"hasAlreadyVotedDown":false,"canUpvote":true,"canDownvote":false,"voteUpUrl":null,"voteDownUrl":null,"voters":[{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/103225-kg.jpg","displayName":"Bukun","profileUrl":"/ambarish","tier":"Master","tierInt":3,"userId":103225,"userName":"ambarish"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/213493-fb.jpg","displayName":"Darragh","profileUrl":"/darraghdog","tier":"Grandmaster","tierInt":4,"userId":213493,"userName":"darraghdog"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/390330-gr.jpg","displayName":"AlexanderGlulkhovtsev","profileUrl":"/glukalex","tier":"Novice","tierInt":0,"userId":390330,"userName":"glukalex"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/740429-kg.jpg","displayName":"Ashwini Swain","profileUrl":"/ash316","tier":"Master","tierInt":3,"userId":740429,"userName":"ash316"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/846032-kg.jpeg","displayName":"Aashita Kesarwani","profileUrl":"/aashita","tier":"Expert","tierInt":2,"userId":846032,"userName":"aashita"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/887461-kg.jpg","displayName":"Hamza El Bouatmani","profileUrl":"/hamzael1","tier":"Contributor","tierInt":1,"userId":887461,"userName":"hamzael1"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/1138645-kg.png","displayName":"Kiurtis","profileUrl":"/kiurtis","tier":"Contributor","tierInt":1,"userId":1138645,"userName":"kiurtis"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/1245336-kg.jpg","displayName":"Janio Martinez Bachmann","profileUrl":"/janiobachmann","tier":"Grandmaster","tierInt":4,"userId":1245336,"userName":"janiobachmann"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/1314380-kg.JPG","displayName":"Paul Mooney","profileUrl":"/paultimothymooney","tier":"Staff","tierInt":5,"userId":1314380,"userName":"paultimothymooney"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/1543900-kg.JPG","displayName":"horohoro","profileUrl":"/horohoro","tier":"Expert","tierInt":2,"userId":1543900,"userName":"horohoro"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/1571785-kg.jpg","displayName":"Shivam Bansal","profileUrl":"/shivamb","tier":"Grandmaster","tierInt":4,"userId":1571785,"userName":"shivamb"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/1875438-kg.jpg","displayName":"Sourabh Jindal","profileUrl":"/sjindalrke","tier":"Contributor","tierInt":1,"userId":1875438,"userName":"sjindalrke"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/2526260-kg.jpg","displayName":"Mayank Bhaskar","profileUrl":"/cataluna84","tier":"Novice","tierInt":0,"userId":2526260,"userName":"cataluna84"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/2583593-kg.jpg","displayName":"Caneiro","profileUrl":"/caneiro","tier":"Contributor","tierInt":1,"userId":2583593,"userName":"caneiro"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/default-thumb.png","displayName":"Siva Karthick","profileUrl":"/sivakitrack","tier":"Contributor","tierInt":1,"userId":3387226,"userName":"sivakitrack"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/3568369-kg.jpg","displayName":"Maguette Mbaye","profileUrl":"/nmaguette","tier":"Contributor","tierInt":1,"userId":3568369,"userName":"nmaguette"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/3716739-kg.jpg","displayName":"Dmitri Kalyaev","profileUrl":"/dmitri9149","tier":"Contributor","tierInt":1,"userId":3716739,"userName":"dmitri9149"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/default-thumb.png","displayName":"Jaime Velazquez","profileUrl":"/jaimevelazquez","tier":"Novice","tierInt":0,"userId":4143046,"userName":"jaimevelazquez"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/default-thumb.png","displayName":"yash kumar19946","profileUrl":"/yashkumar19946","tier":"Novice","tierInt":0,"userId":4306609,"userName":"yashkumar19946"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/5941707-kg.png","displayName":"Nikos Raftogiannis","profileUrl":"/nikosraftogiannis","tier":"Contributor","tierInt":1,"userId":5941707,"userName":"nikosraftogiannis"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/default-thumb.png","displayName":"uestcLJX","profileUrl":"/uestcljx","tier":"Novice","tierInt":0,"userId":6193374,"userName":"uestcljx"},{"avatarThumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/6206416-kg.png","displayName":"Yana Malysheva","profileUrl":"/yanamal","tier":"Expert","tierInt":2,"userId":6206416,"userName":"yanamal"}],"currentUserInfo":null,"showVoters":true,"alwaysShowVoters":true,"kernelId":1300665},"parentDataSource":null,"parentName":"no data sources","parentUrl":"/kaggle/no-data-sources","thumbnailImageUrl":"/static/images/no-datasource.png","canWrite":false,"canAdminister":false,"currentUserForkParentSessionId":null,"currentUserHasForked":false,"forkParentIsRedacted":false,"forkDiffLinesChanged":0,"forkDiffLinesDeleted":0,"forkDiffLinesInserted":0,"forkDiffUrl":null,"forkParentAuthorDisplayName":null,"forkParentAuthorUrl":null,"forkParentTitle":null,"forkParentUrl":null,"canSeeInnerTableOfContents":true,"simplifiedViewer":false,"kernelOutputDataset":null,"disableComments":false,"taskSubmissionInfo":null,"learnSeriesNavigationData":null});performance && performance.mark && performance.mark("KernelViewer.componentCouldBootstrap");</script>

<form action="/morrisb/ipython-magic-functions" id="__AjaxAntiForgeryForm" method="post"><input name="X-XSRF-TOKEN" type="hidden" value="CfDJ8LdUzqlsSWBPr4Ce3rb9VL-OMFsombedWAIFcLLy2ftiHKp4qkxZoOESonvgEklklT_Y0uaWzldW-OmbXeyGLCY9dgX58CMxjlmVDsJOR6gzsl-VsehfJYIkVU4eZ1RC3IcMsanqZHAtxhV8fzdzwbo" /></form>
<script nonce="FiZWW0tnkRJsYlEhXDf4sA==" type="text/x-mathjax-config">
    MathJax.Hub.Config({
    "HTML-CSS": {
    preferredFont: "TeX",
    availableFonts: ["STIX", "TeX"],
    linebreaks: {
    automatic: true
    },
    EqnChunk: (MathJax.Hub.Browser.isMobile ? 10 : 50)
    },
    tex2jax: {
    inlineMath: [["\\(", "\\)"], ["\\\\(", "\\\\)"]],
    displayMath: [["$$", "$$"], ["\\[", "\\]"]],
    processEscapes: true,
    ignoreClass: "tex2jax_ignore|dno"
    },
    TeX: {
    noUndefined: {
    attributes: {
    mathcolor: "red",
    mathbackground: "#FFEEEE",
    mathsize: "90%"
    }
    }
    },
    Macros: {
    href: "{}"
    },
    skipStartupTypeset: true,
    messageStyle: "none",
    extensions: [],
    });
</script>
<script type="text/javascript" nonce="FiZWW0tnkRJsYlEhXDf4sA==">
  window.addEventListener("DOMContentLoaded", () => {
    const head = document.getElementsByTagName("head")[0];
    const useProdHosts = ["www.kaggle.com", "admin.kaggle.com"];
    const subdomain = useProdHosts.includes(window.location.hostname) ? "www" : "staging";

    const lib = document.createElement("script");
    lib.type = "text/javascript";
    lib.src = `https://${subdomain}.kaggleusercontent.com/static/mathjax/2.7.0/MathJax.js?config=TeX-AMS-MML_HTMLorMML`;
    head.appendChild(lib);
  });
</script>


</div>




    </main>
</body>
</html>
