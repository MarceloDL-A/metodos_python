# %%
import pandas as pd
import numpy as np

# Data Wrangling Imports
from datetime import datetime

# Data Analysis Imports
import statistics
import seaborn as sns
from scipy import linalg
from matplotlib import style
from matplotlib import ticker
from scipy import stats
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller

# Data Visualization Imports
#import cufflinks as cf
#import chart_studio.plotly as py
#import plotly.graph_objects as go
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
from matplotlib.gridspec import GridSpec

# Econometry Imports
import pandas_ta as ta

# Other Imports
import os
from itertools import product
import warnings
import talib
warnings.filterwarnings('ignore')
pd.options.display.float_format = "{:.10f}".format

# %% [markdown]
# ### 2- Depois de cadastrar uma conta na [Binance](https://www.binance.com/pt-BR) é necessário inserir os parâmetros key e secret da API

# %%
from binance.client import Client
# %run chaves02.ipynb
client = Client(key,secret)

# %%
# Escolhe o par
TRADING_PAIR = 'BTCBRL'
# Data de Inicio da Captura dos Dados
STARTING_DATE = "5 Mar, 2021"
# Data Final da Captura dos Dados
END_DATE = "12 Mar, 2021"

# %%
def process_message(msg):
    if msg['e'] == 'error':
        bm.stop_socket(conn_key)
        bm.close()
    else:
        pass

# %%
time_res = client.get_server_time()
time_res
# Out:
# {'serverTime': 1615745656052}

# %% [markdown]
# ### 3- Obtenção de informações via API da Binance e construção do dataframe __data__

# %% [markdown]
# ### [Binance Websockets API](https://python-binance.readthedocs.io/en/latest/websockets.html)

# %%
# Importing Binance Websockets API
from binance.client import *
from binance.websockets import BinanceSocketManager
from twisted.internet import reactor

# Initialize Binance Socket Manager
bm = BinanceSocketManager(client, user_timeout=60)
list_messages = []
conn_key = bm.start_trade_socket(TRADING_PAIR, process_message)
bm.start
# Out:
# <bound method Thread.start of <BinanceSocketManager(Thread-6, initial)>>

# %%
candles = client.get_klines(symbol=TRADING_PAIR, interval=Client.KLINE_INTERVAL_1MINUTE)

# %%
# Old Get klines from Binance Python API
#klines = client.get_historical_klines("ONEBNB", Client.KLINE_INTERVAL_1MINUTE, STARTING_DATE, END_DATE)

# %%
indexes = ['Open Time', 'Open', 'High','Low', 'Close', 'Volume', 'Close Time', 'QAV', 'No. Trades', 'Taker BBAV', 'Taker BQAV', 'Ignore']
data = pd.DataFrame(columns=indexes,data=candles)

# %%
data.head
# Out:
# <bound method NDFrame.head of          Open Time             Open             High              Low  \
# 0    1615715700000  342870.00000000  342870.00000000  342870.00000000
# 1    1615715760000  342238.00000000  342238.00000000  342200.00000000
# 2    1615715820000  342105.00000000  342105.00000000  342104.00000000
# 3    1615715880000  341585.00000000  341585.00000000  341585.00000000
# 4    1615715940000  341585.00000000  341585.00000000  341585.00000000
# ..             ...              ...              ...              ...
# 495  1615745400000  337409.00000000  337409.00000000  337100.00000000
# 496  1615745460000  337300.00000000  337300.00000000  337300.00000000
# 497  1615745520000  337250.00000000  337670.00000000  337250.00000000
# 498  1615745580000  337670.00000000  337755.00000000  337532.00000000
# 499  1615745640000  337755.00000000  337755.00000000  337755.00000000
#
#                Close      Volume     Close Time             QAV  No. Trades  \
# ...

# %%
len(data)
# Out:
# 500

# %%
data.to_csv("CryptoBot_202103006Mv001.csv", index = False)

# %%
data = pd.read_csv("CryptoBot_202103006Mv001.csv")

# %%
data.dtypes
data['Open Time'] = data['Open Time'].apply(lambda x: datetime.fromtimestamp(int(x)/1000))
data.set_index(['Open Time'], inplace=True)
# data['Open'] = data['Open'].astype(float)
# data['High'] = data['High'].astype(float)
# data['Low'] = data['Low'].astype(float)
data['Close'] = data['Close'].astype(float)
data['Volume'] = data['Volume'].astype(float)
# data['QAV'] = data['QAV'].astype(float)
# data['Taker BBAV'] = data['Taker BBAV'].astype(float)
# data['Taker BQAV'] = data['Taker BQAV'].astype(float)

# %%
data
# Out:
#                                  Open              High               Low  \
# Open Time
# 2021-03-14 06:55:00 342870.0000000000 342870.0000000000 342870.0000000000
# 2021-03-14 06:56:00 342238.0000000000 342238.0000000000 342200.0000000000
# 2021-03-14 06:57:00 342105.0000000000 342105.0000000000 342104.0000000000
# 2021-03-14 06:58:00 341585.0000000000 341585.0000000000 341585.0000000000
# 2021-03-14 06:59:00 341585.0000000000 341585.0000000000 341585.0000000000
# ...                               ...               ...               ...
# 2021-03-14 15:10:00 337409.0000000000 337409.0000000000 337100.0000000000
# 2021-03-14 15:11:00 337300.0000000000 337300.0000000000 337300.0000000000
# 2021-03-14 15:12:00 337250.0000000000 337670.0000000000 337250.0000000000
# 2021-03-14 15:13:00 337670.0000000000 337755.0000000000 337532.0000000000
# 2021-03-14 15:14:00 337755.0000000000 337755.0000000000 337755.0000000000
#
#                                 Close       Volume     Close Time  \
# ...

# %% [markdown]
# ### 4- Gráficos da informação obtida pela API da Binance e armazenada em __data__
#
# #### [Introduction to Econometrics - G. S. Madalla](https://www.amazon.com.br/Introduction-Econometrics-G-S-Maddala/dp/0471497282)

# %% [markdown]
# ### Análise das informações obitidas pela API da Binance e armazenadas no dataframe __data__

# %% [markdown]
# #### 4.1. Gráficos com legenda automática do dataframe __data__

# %% [markdown]
# #### 4.1.1. Gráficos 'Open', 'High', 'Low', 'Close'

# %%
from matplotlib.pyplot import legend
from matplotlib import pylab
data_0 = data[['Open', 'High', 'Low', 'Close']]
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, data_0)
plt.legend(line, data_0.columns)

# %% [markdown]
# # [5. All Supported Indicators and Functions from Talib librarie](http://mrjbq7.github.io/ta-lib/funcs.html)
# ##### Biblioteca [TA-Lib](http://mrjbq7.github.io/ta-lib/func_groups/momentum_indicators.html)
# - Overlap Studies
# - Momentum Indicators
# - Volume Indicators
# - Volatility Indicators
# - Price Transform
# - Cycle Indicators
# - Pattern Recognition
# - Statistic Functions
# - Math Transform
# - Math Operators

# %%
close = np.array(data['Close'])
high = np.array(data['High'])
low = np.array(data['Low'])

# %% [markdown]
# ## 5.1. Overlap Studies

# %% [raw]
# BBANDS               Bollinger Bands
# DEMA                 Double Exponential Moving Average
# EMA                  Exponential Moving Average
# HT_TRENDLINE         Hilbert Transform - Instantaneous Trendline
# KAMA                 Kaufman Adaptive Moving Average
# MA                   Moving average
# MAMA                 MESA Adaptive Moving Average
# MAVP                 Moving average with variable period
# MIDPOINT             MidPoint over period
# MIDPRICE             Midpoint Price over period
# SAR                  Parabolic SAR
# SAREXT               Parabolic SAR - Extended
# SMA                  Simple Moving Average
# T3                   Triple Exponential Moving Average (T3)
# TEMA                 Triple Exponential Moving Average
# TRIMA                Triangular Moving Average
# WMA                  Weighted Moving Average

# %% [markdown]
# ##### 5.1.1. BBANDS - Bollinger Bands
# Learn more about the Bollinger Bands at tadoc.org.

# %%
data['Close'] = data['Close']*10**10

# %%
np.array(data['Close'].tail())
# Out:
# array([3.37408e+15, 3.37300e+15, 3.37670e+15, 3.37755e+15, 3.37755e+15])

# %% [raw]
# Observação:
# Os valores das linhas de Boillinger estão coincidindo

# %% [raw]
# upperband, middleband, lowerband = talib.BBANDS(close, timeperiod=5, nbdevup=1.7, nbdevdn=1.7, matype=0)

# %%
upperband, middleband, lowerband = talib.BBANDS(np.array(data['Close']), timeperiod=21, nbdevup=1.7, nbdevdn=1.7, matype=0)

# %%
middleband[30:40]
# Out:
# array([3.41069857e+15, 3.41037429e+15, 3.41006190e+15, 3.40977333e+15,
#        3.40934857e+15, 3.40885571e+15, 3.40847714e+15, 3.40773905e+15,
#        3.40706143e+15, 3.40639952e+15])

# %%
upperband[30:40]
# Out:
# array([3.41703201e+15, 3.41642645e+15, 3.41611379e+15, 3.41633912e+15,
#        3.41678425e+15, 3.41700904e+15, 3.41735403e+15, 3.41722871e+15,
#        3.41681472e+15, 3.41630857e+15])

# %%
upperband[0]
# Out:
# nan

# %% [markdown]
# ### Bordas de Boillinger e preços de fechamentos [Close]

# %%
data_Boillinger = pd.DataFrame({"Upperband": upperband, "Middleband":middleband, "Lowerband":lowerband})

data_0 = data_Boillinger[["Upperband", "Middleband", "Lowerband"]]
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, data_0)


#Preço
data_p = pd.DataFrame()
data_p['Close'] = data['Close']

line_p = plt.plot(data_p.index, data_p)


plt.legend(line, data_0.columns)
plt.legend(line_p, data_p.columns)
plt.show()

# %%
df_BBANDS_score = pd.DataFrame()
for i in range(len(data)):
    df_BBANDS_score = df_BBANDS_score.append({"Close": data['Close'][i], "Upperband":upperband[i], "Middleband":middleband[i], "Lowerband":lowerband[i]}, ignore_index = True)

# %%
range(len(data))
# Out:
# range(0, 500)

# %%
data_BBANDS = data_p.dropna().reset_index(drop = True)

# %%
df_BBANDS_score
# Out:
#                           Close                   Lowerband  \
# 0   3428700000000000.0000000000                         NaN
# 1   3422000000000000.0000000000                         NaN
# 2   3421040000000000.0000000000                         NaN
# 3   3415850000000000.0000000000                         NaN
# 4   3415850000000000.0000000000                         NaN
# ..                          ...                         ...
# 495 3374080000000000.0000000000 3360023359825861.5000000000
# 496 3373000000000000.0000000000 3360280543831329.0000000000
# 497 3376700000000000.0000000000 3360363682513706.5000000000
# 498 3377550000000000.0000000000 3360821064092995.0000000000
# 499 3377550000000000.0000000000 3361394355309387.0000000000
#
#                      Middleband                   Upperband
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# ...

# %%
df_BBANDS_score["Close"][0]
# Out:
# 3428700000000000.0

# %% [markdown]
# ## Loop de compra com Bordar de Boillinger

# %%
# Todos os valores estão em reais
M_0 = 100.0

Montante_reais = M_0/2 # Fração do montante na primeira moeda do par
Montante_crypto = M_0/2/df_BBANDS_score["Close"][0] # Fração da criptomoeda correspondente ao complemento do investimento inicial.
                                                    # É o valor em reais dividido pelo valor de fechamento da criptomoeda no momento da compra.
Montante_total = M_0
df_BBANDS_score["Upper Touch"] = 0.0
df_BBANDS_score["Down Touch"] = 0.0
df_BBANDS_score["Ganho [%]"] = 0.0
df_BBANDS_score["Montante_total"] = Montante_total
change = ""
last_change = "" # Toque inicial na linha de Boilliger é vazio
band_count = 0
for i in range(len(df_BBANDS_score)):
    
    last_change = change
    Montante_total = Montante_reais + Montante_crypto*df_BBANDS_score['Close'][i]
    df_BBANDS_score["Montante_total"][i] = Montante_total
    df_BBANDS_score["Ganho [%]"][i] = (Montante_total - M_0)/M_0*100
    if (df_BBANDS_score['Close'][i] - df_BBANDS_score['Upperband'][i])>0.0:
        df_BBANDS_score["Upper Touch"][i] = 1
        change = "UP"
        
    if ((df_BBANDS_score['Close'][i] - df_BBANDS_score['Lowerband'][i])<0.0):
        df_BBANDS_score["Down Touch"][i] = 1
        change = "DOWN"
    
    if (last_change != change):
        if (last_change == "UP"):
            venda_cripto = 0.03*Montante_crypto*df_BBANDS_score['Close'][i] # Venda das criptos em reais
            Montante_crypto -= 0.03*Montante_crypto # Diminui o montante de crypto moedas
            Montante_reais += venda_cripto # Aumenta o montante de reais
        if (last_change == "DOWN"):
            compra_cripto = 0.03*Montante_reais
            Montante_reais -= compra_cripto
            Montante_crypto += compra_cripto/df_BBANDS_score['Close'][i]
        #Conta o número de mudanças entre compra e venda de acordo com os toques alternados nas Bordas de Boillinger
        band_count += 1

# %% [markdown]
# #### Número de toques alternados nas Bandas de Boillinger

# %%
band_count
# Out:
# 12

# %%
df_BBANDS_score
# Out:
#                           Close                   Lowerband  \
# 0   3428700000000000.0000000000                         NaN
# 1   3422000000000000.0000000000                         NaN
# 2   3421040000000000.0000000000                         NaN
# 3   3415850000000000.0000000000                         NaN
# 4   3415850000000000.0000000000                         NaN
# ..                          ...                         ...
# 495 3374080000000000.0000000000 3360023359825861.5000000000
# 496 3373000000000000.0000000000 3360280543831329.0000000000
# 497 3376700000000000.0000000000 3360363682513706.5000000000
# 498 3377550000000000.0000000000 3360821064092995.0000000000
# 499 3377550000000000.0000000000 3361394355309387.0000000000
#
#                      Middleband                   Upperband  Upper Touch  \
# 0                           NaN                         NaN 0.0000000000
# 1                           NaN                         NaN 0.0000000000
# ...

# %%
df_BBANDS_score[df_BBANDS_score["Ganho [%]"]<0.0].sum()
# Out:
# Close            1684965080000000000.0000000000
# Lowerband        1615960081034646016.0000000000
# Middleband       1620480014761904640.0000000000
# Upperband        1624999948489163264.0000000000
# Upper Touch                       30.0000000000
# Down Touch                        65.0000000000
# Ganho [%]                       -377.7634882129
# Montante_total                 49522.2365117871
# dtype: float64

# %%
df_BBANDS_score[df_BBANDS_score["Ganho [%]"]>0.0].sum()
# Out:
# Close            0.0000000000
# Lowerband        0.0000000000
# Middleband       0.0000000000
# Upperband        0.0000000000
# Upper Touch      0.0000000000
# Down Touch       0.0000000000
# Ganho [%]        0.0000000000
# Montante_total   0.0000000000
# dtype: float64

# %%
df_BBANDS_score.tail()
# Out:
#                           Close                   Lowerband  \
# 495 3374080000000000.0000000000 3360023359825861.5000000000
# 496 3373000000000000.0000000000 3360280543831329.0000000000
# 497 3376700000000000.0000000000 3360363682513706.5000000000
# 498 3377550000000000.0000000000 3360821064092995.0000000000
# 499 3377550000000000.0000000000 3361394355309387.0000000000
#
#                      Middleband                   Upperband  Upper Touch  \
# 495 3369489047619047.5000000000 3378954735412233.5000000000 0.0000000000
# 496 3369776666666666.5000000000 3379272789502004.0000000000 0.0000000000
# 497 3370167142857143.0000000000 3379970603200579.5000000000 0.0000000000
# 498 3370765238095238.0000000000 3380709412097481.0000000000 0.0000000000
# 499 3371367142857143.0000000000 3381339930404899.0000000000 0.0000000000
#
#       Down Touch     Ganho [%]  Montante_total
# 495 0.0000000000 -0.8049453665   99.1950546335
# 496 0.0000000000 -0.8211472236   99.1788527764
# ...

# %%
close
# Out:
# array([342870., 342200., 342104., 341585., 341585., 341861., 341961.,
#        342000., 341589., 341200., 341580., 341350., 340906., 340906.,
#        341035., 340701., 341322., 341322., 341288., 341288., 340002.,
#        340978., 341000., 341285., 341285., 340856., 341284., 341284.,
#        341281., 341276., 340238., 340899., 340694., 340300., 340014.,
#        340000., 339906., 339772., 339899., 339898., 339897., 339218.,
#        339082., 338543., 338521., 338943., 338520., 337738., 339198.,
#        338843., 339150., 339896., 339281., 339491., 339475., 339450.,
#        339400., 338560., 337899., 338224., 339163., 338743., 338600.,
#        338869., 338513., 338575., 338869., 338867., 338864., 338863.,
#        338277., 338277., 338086., 337700., 337923., 338276., 337422.,
#        337556., 336700., 337604., 337251., 337444., 336931., 336184.,
#        336999., 337000., 336968., 336100., 335500., 335300., 335777.,
# ...

# %%
macd, macdsignal, macdhist = talib.MACD(close, fastperiod=12, slowperiod=26, signalperiod=9)

# %%
#Bordas de Boillinger
data_MACD = pd.DataFrame({"macd": macd, "macdsignal":macdsignal, "macdhist":macdhist})

data_MACD0 = data_MACD[["macd", "macdsignal", "macdhist"]]
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, data_MACD0)

data_p = pd.DataFrame()
data_p['Close'] = data['Close']
plt.legend(line, data_MACD0.columns)
plt.show()

# %% [markdown]
# ##### 5.1.2. DEMA - Double Exponential Moving Average

# %%
real = talib.DEMA(close, timeperiod=30)

# %%
# data_Boillinger = pd.DataFrame({"Upperband": upperband, "Middleband":middleband, "Lowerband":lowerband})

# data_0 = data_Boillinger[["Upperband", "Middleband", "Lowerband"]]
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, real)
plt.legend(line, data_0.columns)

# %% [raw]
# Learn more about the Double Exponential Moving Average at tadoc.org.

# %% [markdown]
# ##### 5.1.3. EMA - Exponential Moving Average

# %% [raw]
# NOTE: The EMA function has an unstable period.

# %%
real = talib.EMA(close, timeperiod=30)
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, real)
plt.legend(line, data_0.columns)

# %% [raw]
# Learn more about the Exponential Moving Average at tadoc.org.

# %% [markdown]
# ##### 5.1.4. HT_TRENDLINE - Hilbert Transform - Instantaneous Trendline

# %% [raw]
# NOTE: The HT_TRENDLINE function has an unstable period.

# %%
real = talib.HT_TRENDLINE(close)
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, real)
plt.legend(line, data_0.columns)

# %% [raw]
# Learn more about the Hilbert Transform - Instantaneous Trendline at tadoc.org.

# %% [markdown]
# ##### 5.1.5. KAMA - Kaufman Adaptive Moving Average
# NOTE: The KAMA function has an unstable period.

# %%
real = talib.KAMA(close, timeperiod=30)
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, real)
plt.legend(line, data_0.columns)

# %% [raw]
# Learn more about the Kaufman Adaptive Moving Average at tadoc.org.

# %% [markdown]
# ##### 5.1.6. MA - Moving average

# %%
real = talib.MA(close, timeperiod=30, matype=0)
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, real)
plt.legend(line, data_0.columns)

# %% [markdown]
# ##### 5.1.7. MAMA - MESA Adaptive Moving Average
# NOTE: The MAMA function has an unstable period.

# %%
mama, fama = talib.MAMA(close, fastlimit=0.5, slowlimit=0.05)
data_Boillinger = pd.DataFrame({"MAMA": mama, "FAMA":fama})

data_0 = data_Boillinger[["MAMA", "FAMA"]]
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, data_0)
plt.legend(line, data_0.columns)

# %% [raw]
# Learn more about the MESA Adaptive Moving Average at tadoc.org.

# %% [markdown]
# ##### 5.1.8. MAVP - Moving average with variable period

# %% [markdown]
# ###### ***np.array(data['Close'] é apenas um exempo para o parametro periods. É preciso analisar melhor esse parâmetro.

# %%
real = talib.MAVP(close, periods=np.array(data['Close']), minperiod=2, maxperiod=30, matype=0)
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, real)
plt.legend(line, data_0.columns)

# %% [markdown]
# ##### 5.1.9. MIDPOINT - MidPoint over period

# %%
real = talib.MIDPOINT(close, timeperiod=14)
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, real)
plt.legend(line, data_0.columns)

# %% [raw]
# Learn more about the MidPoint over period at tadoc.org.

# %% [markdown]
# ##### 5.1.10. MIDPRICE - Midpoint Price over period

# %%
real = talib.MIDPRICE(high, low, timeperiod=14)
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, real)
plt.legend(line, data_0.columns)

# %% [raw]
# Learn more about the Midpoint Price over period at tadoc.org.

# %% [markdown]
# ##### 5.1.11. SAR - Parabolic SAR
# real = talib.SAR(high, low, acceleration=0, maximum=0)
# Learn more about the Parabolic SAR at tadoc.org.

# %% [markdown]
# ##### 5.1.12. SAREXT - Parabolic SAR - Extended

# %%
real = talib.SAREXT(high, low, startvalue=0, offsetonreverse=0, accelerationinitlong=0, accelerationlong=0, accelerationmaxlong=0, accelerationinitshort=0, accelerationshort=0, accelerationmaxshort=0)
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, real)
plt.legend(line, data_0.columns)

# %% [markdown]
# ##### 5.1.13. SMA - Simple Moving Average

# %%
real = talib.SMA(close, timeperiod=30)
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, real)
plt.legend(line, data_0.columns)

# %% [raw]
# Learn more about the Simple Moving Average at tadoc.org.

# %% [markdown]
# ##### 5.1.14. T3 - Triple Exponential Moving Average (T3)

# %% [raw]
# NOTE: The T3 function has an unstable period.

# %%
real = talib.T3(close, timeperiod=5, vfactor=0)
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, real)
plt.legend(line, data_0.columns)

# %% [raw]
# Learn more about the Triple Exponential Moving Average (T3) at tadoc.org.

# %% [markdown]
# ##### 5.1.15. TEMA - Triple Exponential Moving Average

# %%
real = talib.TEMA(close, timeperiod=30)
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, real)
plt.legend(line, data_0.columns)

# %% [raw]
# Learn more about the Triple Exponential Moving Average at tadoc.org.

# %% [markdown]
# ##### 5.1.16. TRIMA - Triangular Moving Average

# %%
real = talib.TRIMA(close, timeperiod=30)
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, real)
plt.legend(line, data_0.columns)

# %% [raw]
# Learn more about the Triangular Moving Average at tadoc.org.

# %% [markdown]
# ##### 5.1.17. WMA - Weighted Moving Average

# %%
real = talib.WMA(close, timeperiod=30)
plt.figure(figsize=(12,5), dpi=100)
line = plt.plot(data.index, real)
plt.legend(line, data_0.columns)

# %% [markdown]
# ## [5.2. Momentum Indicators](http://mrjbq7.github.io/ta-lib/func_groups/momentum_indicators.html)

# %%
data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Close Time', 'QAV',
#        'No. Trades', 'Taker BBAV', 'Taker BQAV', 'Ignore'],
#       dtype='object')

# %%
open_ = np.array(data["Open"])
volume = np.array(data['Volume'])

# %% [raw]
# ADX                  Average Directional Movement Index
# ADXR                 Average Directional Movement Index Rating
# APO                  Absolute Price Oscillator
# AROON                Aroon
# AROONOSC             Aroon Oscillator
# BOP                  Balance Of Power
# CCI                  Commodity Channel Index
# CMO                  Chande Momentum Oscillator
# DX                   Directional Movement Index
# MACD                 Moving Average Convergence/Divergence
# MACDEXT              MACD with controllable MA type
# MACDFIX              Moving Average Convergence/Divergence Fix 12/26
# MFI                  Money Flow Index
# MINUS_DI             Minus Directional Indicator
# MINUS_DM             Minus Directional Movement
# MOM                  Momentum
# PLUS_DI              Plus Directional Indicator
# PLUS_DM              Plus Directional Movement
# PPO                  Percentage Price Oscillator
# ROC                  Rate of change : ((price/prevPrice)-1)*100
# ROCP                 Rate of change Percentage: (price-prevPrice)/prevPrice
# ROCR                 Rate of change ratio: (price/prevPrice)
# ROCR100              Rate of change ratio 100 scale: (price/prevPrice)*100
# RSI                  Relative Strength Index
# STOCH                Stochastic
# STOCHF               Stochastic Fast
# STOCHRSI             Stochastic Relative Strength Index
# TRIX                 1-day Rate-Of-Change (ROC) of a Triple Smooth EMA
# ULTOSC               Ultimate Oscillator
# WILLR                Williams' %R

# %% [markdown]
# ### 5.2.1. ADX - Average Directional Movement Index
# NOTE: The ADX function has an unstable period.

# %%
real = talib.ADX(high, low, close, timeperiod=14)

# %% [markdown]
# Learn more about the Average Directional Movement Index at tadoc.org.

# %% [markdown]
# ### 5.2.1. ADXR - Average Directional Movement Index Rating
# NOTE: The ADXR function has an unstable period.

# %%
real = talib.ADXR(high, low, close, timeperiod=14)

# %% [markdown]
# Learn more about the Average Directional Movement Index Rating at tadoc.org.

# %% [markdown]
# ### 5.2.1. APO - Absolute Price Oscillator

# %%
real = talib.APO(close, fastperiod=12, slowperiod=26, matype=0)

# %% [markdown]
# Learn more about the Absolute Price Oscillator at tadoc.org.

# %% [markdown]
# ### 5.2.1. AROON - Aroon

# %%
aroondown, aroonup = talib.AROON(high, low, timeperiod=14)

# %% [markdown]
# Learn more about the Aroon at tadoc.org.

# %% [markdown]
# ### 5.2.1. AROONOSC - Aroon Oscillator

# %%
real = talib.AROONOSC(high, low, timeperiod=14)

# %% [markdown]
# Learn more about the Aroon Oscillator at tadoc.org.

# %% [markdown]
# ### 5.2.1. BOP - Balance Of Power

# %%
real = talib.BOP(open_, high, low, close)

# %% [markdown]
# Learn more about the Balance Of Power at tadoc.org.

# %% [markdown]
# ### 5.2.1. CCI - Commodity Channel Index

# %%
real = talib.CCI(high, low, close, timeperiod=14)

# %% [markdown]
# Learn more about the Commodity Channel Index at tadoc.org.

# %% [markdown]
# ### 5.2.1. CMO - Chande Momentum Oscillator
# NOTE: The CMO function has an unstable period.

# %%
real = talib.CMO(close, timeperiod=14)

# %% [markdown]
# Learn more about the Chande Momentum Oscillator at tadoc.org.

# %% [markdown]
# ### 5.2.1. DX - Directional Movement Index
# NOTE: The DX function has an unstable period.

# %%
real = talib.DX(high, low, close, timeperiod=14)

# %% [markdown]
# Learn more about the Directional Movement Index at tadoc.org.

# %% [markdown]
# ### 5.2.1. MACD - Moving Average Convergence/Divergence

# %%
macd, macdsignal, macdhist = talib.MACD(close, fastperiod=12, slowperiod=26, signalperiod=9)

# %% [markdown]
# Learn more about the Moving Average Convergence/Divergence at tadoc.org.

# %% [markdown]
# ### 5.2.1. MACDEXT - MACD with controllable MA type

# %%
macd, macdsignal, macdhist = talib.MACDEXT(close, fastperiod=12, fastmatype=0, slowperiod=26, slowmatype=0, signalperiod=9, signalmatype=0)

# %% [markdown]
# ### 5.2.1. MACDFIX - Moving Average Convergence/Divergence Fix 12/26

# %%
macd, macdsignal, macdhist = talib.MACDFIX(close, signalperiod=9)

# %% [markdown]
# ### 5.2.1. MFI - Money Flow Index
# NOTE: The MFI function has an unstable period.

# %%
real = talib.MFI(high, low, close, volume, timeperiod=14)

# %% [markdown]
# Learn more about the Money Flow Index at tadoc.org.

# %% [markdown]
# ### 5.2.1. MINUS_DI - Minus Directional Indicator
# NOTE: The MINUS_DI function has an unstable period.

# %%
real = talib.MINUS_DI(high, low, close, timeperiod=14)

# %% [markdown]
# Learn more about the Minus Directional Indicator at tadoc.org.

# %% [markdown]
# ### 5.2.1. MINUS_DM - Minus Directional Movement
# NOTE: The MINUS_DM function has an unstable period.

# %%
real = talib.MINUS_DM(high, low, timeperiod=14)

# %% [markdown]
# Learn more about the Minus Directional Movement at tadoc.org.

# %% [markdown]
# ### 5.2.1. MOM - Momentum

# %%
real = talib.MOM(close, timeperiod=10)

# %% [markdown]
# Learn more about the Momentum at tadoc.org.

# %% [markdown]
# ### 5.2.1. PLUS_DI - Plus Directional Indicator
# NOTE: The PLUS_DI function has an unstable period.

# %%
real = talib.PLUS_DI(high, low, close, timeperiod=14)

# %% [markdown]
# Learn more about the Plus Directional Indicator at tadoc.org.

# %% [markdown]
# ### 5.2.1. PLUS_DM - Plus Directional Movement
# NOTE: The PLUS_DM function has an unstable period.

# %%
real = talib.PLUS_DM(high, low, timeperiod=14)

# %% [markdown]
# Learn more about the Plus Directional Movement at tadoc.org.

# %% [markdown]
# ### 5.2.1. PPO - Percentage Price Oscillator

# %%
real = talib.PPO(close, fastperiod=12, slowperiod=26, matype=0)

# %% [markdown]
# Learn more about the Percentage Price Oscillator at tadoc.org.

# %% [markdown]
# ### 5.2.1. ROC - Rate of change : ((price/prevPrice)-1)*100

# %%
real = talib.ROC(close, timeperiod=10)

# %% [markdown]
# Learn more about the Rate of change : ((price/prevPrice)-1)*100 at tadoc.org.

# %% [markdown]
# ### 5.2.1. ROCP - Rate of change Percentage: (price-prevPrice)/prevPrice

# %%
real = talib.ROCP(close, timeperiod=10)

# %% [markdown]
# Learn more about the Rate of change Percentage: (price-prevPrice)/prevPrice at tadoc.org.

# %% [markdown]
# ### 5.2.1. ROCR - Rate of change ratio: (price/prevPrice)

# %%
real = talib.ROCR(close, timeperiod=10)

# %% [markdown]
# Learn more about the Rate of change ratio: (price/prevPrice) at tadoc.org.

# %% [markdown]
# ### 5.2.1. ROCR100 - Rate of change ratio 100 scale: (price/prevPrice)*100

# %%
real = talib.ROCR100(close, timeperiod=10)

# %% [markdown]
# Learn more about the Rate of change ratio 100 scale: (price/prevPrice)*100 at tadoc.org.

# %% [markdown]
# ### 5.2.1. RSI - Relative Strength Index
# NOTE: The RSI function has an unstable period.

# %%
real = talib.RSI(close, timeperiod=14)

# %% [markdown]
# Learn more about the Relative Strength Index at tadoc.org.

# %% [markdown]
# ### 5.2.1. STOCH - Stochastic

# %%
slowk, slowd = talib.STOCH(high, low, close, fastk_period=5, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)

# %% [markdown]
# Learn more about the Stochastic at tadoc.org.

# %% [markdown]
# ### 5.2.1. STOCHF - Stochastic Fast

# %%
fastk, fastd = talib.STOCHF(high, low, close, fastk_period=5, fastd_period=3, fastd_matype=0)

# %% [markdown]
# Learn more about the Stochastic Fast at tadoc.org.

# %% [markdown]
# ### 5.2.1. STOCHRSI - Stochastic Relative Strength Index

# %% [markdown]
# NOTE: The STOCHRSI function has an unstable period.

# %%
fastk, fastd = talib.STOCHRSI(close, timeperiod=14, fastk_period=5, fastd_period=3, fastd_matype=0)

# %% [markdown]
# Learn more about the Stochastic Relative Strength Index at tadoc.org.

# %% [markdown]
# ### 5.2.1. TRIX - 1-day Rate-Of-Change (ROC) of a Triple Smooth EMA

# %%
real = talib.TRIX(close, timeperiod=30)

# %% [markdown]
# Learn more about the 1-day Rate-Of-Change (ROC) of a Triple Smooth EMA at tadoc.org.

# %% [markdown]
# ### 5.2.1. ULTOSC - Ultimate Oscillator

# %%
real = talib.ULTOSC(high, low, close, timeperiod1=7, timeperiod2=14, timeperiod3=28)

# %% [markdown]
# Learn more about the Ultimate Oscillator at tadoc.org.

# %% [markdown]
# ### 5.2.1. WILLR - Williams' %R

# %%
real = talib.WILLR(high, low, close, timeperiod=14)

# %% [markdown]
# Learn more about the Williams' %R at tadoc.org.

# %% [markdown]
# ## [5.3. Volume Indicators](http://mrjbq7.github.io/ta-lib/func_groups/volume_indicators.html)

# %% [markdown]
# ### 5.3.1. AD - Chaikin A/D Line

# %%
real = talib.AD(high, low, close, volume)

# %% [markdown]
# Learn more about the Chaikin A/D Line at tadoc.org.

# %% [markdown]
# ### 5.3.2. ADOSC - Chaikin A/D Oscillator

# %%
real = talib.ADOSC(high, low, close, volume, fastperiod=3, slowperiod=10)

# %% [markdown]
# Learn more about the Chaikin A/D Oscillator at tadoc.org.

# %% [markdown]
# ### 5.3.3. OBV - On Balance Volume

# %%
real = talib.OBV(close, volume)

# %% [markdown]
# Learn more about the On Balance Volume at tadoc.org.

# %% [markdown]
# ## [5.4. Cycle Indicators](http://mrjbq7.github.io/ta-lib/func_groups/cycle_indicators.html)

# %% [raw]
# HT_DCPERIOD          Hilbert Transform - Dominant Cycle Period
# HT_DCPHASE           Hilbert Transform - Dominant Cycle Phase
# HT_PHASOR            Hilbert Transform - Phasor Components
# HT_SINE              Hilbert Transform - SineWave
# HT_TRENDMODE         Hilbert Transform - Trend vs Cycle Mode

# %% [markdown]
# Cycle Indicator Functions

# %% [markdown]
# ### 5.4.1. HT_DCPERIOD - Hilbert Transform - Dominant Cycle Period

# %% [markdown]
# NOTE: The HT_DCPERIOD function has an unstable period.

# %%
real = talib.HT_DCPERIOD(close)

# %% [markdown]
# Learn more about the Hilbert Transform - Dominant Cycle Period at tadoc.org.

# %% [markdown]
# ### 5.4.2. HT_DCPHASE - Hilbert Transform - Dominant Cycle Phase

# %% [markdown]
# NOTE: The HT_DCPHASE function has an unstable period.

# %%
real = talib.HT_DCPHASE(close)

# %% [markdown]
# Learn more about the Hilbert Transform - Dominant Cycle Phase at tadoc.org.

# %% [markdown]
# ### 5.4.3. HT_PHASOR - Hilbert Transform - Phasor Components

# %% [markdown]
# NOTE: The HT_PHASOR function has an unstable period.

# %%
inphase, quadrature = talib.HT_PHASOR(close)

# %% [markdown]
# Learn more about the Hilbert Transform - Phasor Components at tadoc.org.

# %% [markdown]
# ### 5.4.4. HT_SINE - Hilbert Transform - SineWave

# %% [markdown]
# NOTE: The HT_SINE function has an unstable period.

# %%
sine, leadsine = talib.HT_SINE(close)

# %% [markdown]
# Learn more about the Hilbert Transform - SineWave at tadoc.org.

# %% [markdown]
# ### 5.4.4. HT_TRENDMODE - Hilbert Transform - Trend vs Cycle Mode

# %% [markdown]
# NOTE: The HT_TRENDMODE function has an unstable period.

# %%
integer = talib.HT_TRENDMODE(close)

# %% [markdown]
# Learn more about the Hilbert Transform - Trend vs Cycle Mode at tadoc.org.

# %% [markdown]
# ## [5.5. Price Transform](http://mrjbq7.github.io/ta-lib/func_groups/price_transform.html)

# %% [raw]
# AVGPRICE             Average Price
# MEDPRICE             Median Price
# TYPPRICE             Typical Price
# WCLPRICE             Weighted Close Price

# %% [markdown]
# Price Transform Functions
# ### 5.5.1. AVGPRICE - Average Price

# %%
real = talib.AVGPRICE(open_, high, low, close)

# %% [markdown]
# Learn more about the Average Price at tadoc.org.
#
# ### 5.5.2. MEDPRICE - Median Price

# %%
real = talib.MEDPRICE(high, low)

# %% [markdown]
# Learn more about the Median Price at tadoc.org.
#
# ### 5.5.3. TYPPRICE - Typical Price

# %%
real = talib.TYPPRICE(high, low, close)

# %% [markdown]
# Learn more about the Typical Price at tadoc.org.
#
# ### 5.5.4. WCLPRICE - Weighted Close Price

# %%
real = talib.WCLPRICE(high, low, close)

# %% [markdown]
# Learn more about the Weighted Close Price at tadoc.org.

# %% [markdown]
# ## [5.6. Volatility Indicators](http://mrjbq7.github.io/ta-lib/func_groups/volatility_indicators.html)

# %% [raw]
# ATR                  Average True Range
# NATR                 Normalized Average True Range
# TRANGE               True Range

# %% [markdown]
# Volatility Indicator Functions
# ### 5.6.1. ATR - Average True Range
# NOTE: The ATR function has an unstable period.

# %%
real = talib.ATR(high, low, close, timeperiod=14)

# %% [markdown]
# Learn more about the Average True Range at tadoc.org.
#
# ### 5.6.1. NATR - Normalized Average True Range
# NOTE: The NATR function has an unstable period.

# %%
real = talib.NATR(high, low, close, timeperiod=14)

# %% [markdown]
# Learn more about the Normalized Average True Range at tadoc.org.
#
# ### 5.6.1. TRANGE - True Range

# %%
real = talib.TRANGE(high, low, close)

# %% [markdown]
# Learn more about the True Range at tadoc.org.

# %% [markdown]
# ## [5.7. Pattern Recognition](http://mrjbq7.github.io/ta-lib/func_groups/pattern_recognition.html)

# %% [raw]
# CDL2CROWS            Two Crows
# CDL3BLACKCROWS       Three Black Crows
# CDL3INSIDE           Three Inside Up/Down
# CDL3LINESTRIKE       Three-Line Strike
# CDL3OUTSIDE          Three Outside Up/Down
# CDL3STARSINSOUTH     Three Stars In The South
# CDL3WHITESOLDIERS    Three Advancing White Soldiers
# CDLABANDONEDBABY     Abandoned Baby
# CDLADVANCEBLOCK      Advance Block
# CDLBELTHOLD          Belt-hold
# CDLBREAKAWAY         Breakaway
# CDLCLOSINGMARUBOZU   Closing Marubozu
# CDLCONCEALBABYSWALL  Concealing Baby Swallow
# CDLCOUNTERATTACK     Counterattack
# CDLDARKCLOUDCOVER    Dark Cloud Cover
# CDLDOJI              Doji
# CDLDOJISTAR          Doji Star
# CDLDRAGONFLYDOJI     Dragonfly Doji
# CDLENGULFING         Engulfing Pattern
# CDLEVENINGDOJISTAR   Evening Doji Star
# CDLEVENINGSTAR       Evening Star
# CDLGAPSIDESIDEWHITE  Up/Down-gap side-by-side white lines
# CDLGRAVESTONEDOJI    Gravestone Doji
# CDLHAMMER            Hammer
# CDLHANGINGMAN        Hanging Man
# CDLHARAMI            Harami Pattern
# CDLHARAMICROSS       Harami Cross Pattern
# CDLHIGHWAVE          High-Wave Candle
# CDLHIKKAKE           Hikkake Pattern
# CDLHIKKAKEMOD        Modified Hikkake Pattern
# CDLHOMINGPIGEON      Homing Pigeon
# CDLIDENTICAL3CROWS   Identical Three Crows
# CDLINNECK            In-Neck Pattern
# CDLINVERTEDHAMMER    Inverted Hammer
# CDLKICKING           Kicking
# CDLKICKINGBYLENGTH   Kicking - bull/bear determined by the longer marubozu
# CDLLADDERBOTTOM      Ladder Bottom
# CDLLONGLEGGEDDOJI    Long Legged Doji
# CDLLONGLINE          Long Line Candle
# CDLMARUBOZU          Marubozu
# CDLMATCHINGLOW       Matching Low
# CDLMATHOLD           Mat Hold
# CDLMORNINGDOJISTAR   Morning Doji Star
# CDLMORNINGSTAR       Morning Star
# CDLONNECK            On-Neck Pattern
# CDLPIERCING          Piercing Pattern
# CDLRICKSHAWMAN       Rickshaw Man
# CDLRISEFALL3METHODS  Rising/Falling Three Methods
# CDLSEPARATINGLINES   Separating Lines
# CDLSHOOTINGSTAR      Shooting Star
# CDLSHORTLINE         Short Line Candle
# CDLSPINNINGTOP       Spinning Top
# CDLSTALLEDPATTERN    Stalled Pattern
# CDLSTICKSANDWICH     Stick Sandwich
# CDLTAKURI            Takuri (Dragonfly Doji with very long lower shadow)
# CDLTASUKIGAP         Tasuki Gap
# CDLTHRUSTING         Thrusting Pattern
# CDLTRISTAR           Tristar Pattern
# CDLUNIQUE3RIVER      Unique 3 River
# CDLUPSIDEGAP2CROWS   Upside Gap Two Crows
# CDLXSIDEGAP3METHODS  Upside/Downside Gap Three Methods

# %% [markdown]
# ## Pattern Recognition Functions

# %% [markdown]
# ### 5.7.1. CDL2CROWS - Two Crows

# %%
integer = talib.CDL2CROWS(open_, high, low, close)

# %% [markdown]
# ### 5.7.2. CDL3BLACKCROWS - Three Black Crows

# %%
integer = talib.CDL3BLACKCROWS(open_, high, low, close)

# %% [markdown]
# ### 5.7.3. CDL3INSIDE - Three Inside Up/Down

# %%
integer = talib.CDL3INSIDE(open_, high, low, close)

# %% [markdown]
# ### 5.7.4. CDL3LINESTRIKE - Three-Line Strike

# %%
integer = talib.CDL3LINESTRIKE(open_, high, low, close)

# %% [markdown]
# ### 5.7.5. CDL3OUTSIDE - Three Outside Up/Down

# %%
integer = talib.CDL3OUTSIDE(open_, high, low, close)

# %% [markdown]
# ### 5.7.6. CDL3STARSINSOUTH - Three Stars In The South

# %%
integer = talib.CDL3STARSINSOUTH(open_, high, low, close)

# %% [markdown]
# ### 5.7.7. CDL3WHITESOLDIERS - Three Advancing White Soldiers

# %%
integer = talib.CDL3WHITESOLDIERS(open_, high, low, close)

# %% [markdown]
# ### 5.7.8. CDLABANDONEDBABY - Abandoned Baby

# %%
integer = talib.CDLABANDONEDBABY(open_, high, low, close, penetration=0)

# %% [markdown]
# ### 5.7.9. CDLADVANCEBLOCK - Advance Block

# %%
integer = talib.CDLADVANCEBLOCK(open_, high, low, close)

# %% [markdown]
# ### 5.7.10. CDLBELTHOLD - Belt-hold

# %%
integer = talib.CDLBELTHOLD(open_, high, low, close)

# %% [markdown]
# ### 5.7.11. CDLBREAKAWAY - Breakaway

# %%
integer = talib.CDLBREAKAWAY(open_, high, low, close)

# %% [markdown]
# ### 5.7.12. CDLCLOSINGMARUBOZU - Closing Marubozu

# %%
integer = talib.CDLCLOSINGMARUBOZU(open_, high, low, close)

# %% [markdown]
# ### 5.7.13. CDLCONCEALBABYSWALL - Concealing Baby Swallow

# %%
integer = talib.CDLCONCEALBABYSWALL(open_, high, low, close)

# %% [markdown]
# ### 5.7.14. CDLCOUNTERATTACK - Counterattack

# %%
integer = talib.CDLCOUNTERATTACK(open_, high, low, close)

# %% [markdown]
# ### 5.7.15. CDLDARKCLOUDCOVER - Dark Cloud Cover

# %%
integer = talib.CDLDARKCLOUDCOVER(open_, high, low, close, penetration=0)

# %% [markdown]
# ### 5.7.16. CDLDOJI - Doji

# %%
integer = talib.CDLDOJI(open_, high, low, close)

# %% [markdown]
# ### 5.7.17. CDLDOJISTAR - Doji Star

# %%
integer = talib.CDLDOJISTAR(open_, high, low, close)

# %% [markdown]
# ### 5.7.18. CDLDRAGONFLYDOJI - Dragonfly Doji

# %%
integer = talib.CDLDRAGONFLYDOJI(open_, high, low, close)

# %% [markdown]
# ### 5.7.19. CDLENGULFING - Engulfing Pattern

# %%
integer = talib.CDLENGULFING(open_, high, low, close)

# %% [markdown]
# ### 5.7.20. CDLEVENINGDOJISTAR - Evening Doji Star

# %%
integer = talib.CDLEVENINGDOJISTAR(open_, high, low, close, penetration=0)

# %% [markdown]
# ### 5.7.21. CDLEVENINGSTAR - Evening Star

# %%
integer = talib.CDLEVENINGSTAR(open_, high, low, close, penetration=0)

# %% [markdown]
# ### 5.7.22. CDLGAPSIDESIDEWHITE - Up/Down-gap side-by-side white lines

# %%
integer = talib.CDLGAPSIDESIDEWHITE(open_, high, low, close)

# %% [markdown]
# ### 5.7.23. CDLGRAVESTONEDOJI - Gravestone Doji

# %%
integer = talib.CDLGRAVESTONEDOJI(open_, high, low, close)

# %% [markdown]
# ### 5.7.24. CDLHAMMER - Hammer

# %%
integer = talib.CDLHAMMER(open_, high, low, close)

# %% [markdown]
# ### 5.7.25. CDLHANGINGMAN - Hanging Man

# %%
integer = talib.CDLHANGINGMAN(open_, high, low, close)

# %% [markdown]
# ### 5.7.26. CDLHARAMI - Harami Pattern

# %%
integer = talib.CDLHARAMI(open_, high, low, close)

# %% [markdown]
# ### 5.7.27. CDLHARAMICROSS - Harami Cross Pattern

# %%
integer = talib.CDLHARAMICROSS(open_, high, low, close)

# %% [markdown]
# ### 5.7.28. CDLHIGHWAVE - High-Wave Candle

# %%
integer = talib.CDLHIGHWAVE(open_, high, low, close)

# %% [markdown]
# ### 5.7.29. CDLHIKKAKE - Hikkake Pattern

# %%
integer = talib.CDLHIKKAKE(open_, high, low, close)

# %% [markdown]
# ### 5.7.30. CDLHIKKAKEMOD - Modified Hikkake Pattern

# %%
integer = talib.CDLHIKKAKEMOD(open_, high, low, close)

# %% [markdown]
# ### 5.7.31. CDLHOMINGPIGEON - Homing Pigeon

# %%
integer = talib.CDLHOMINGPIGEON(open_, high, low, close)

# %% [markdown]
# ### 5.7.32. CDLIDENTICAL3CROWS - Identical Three Crows

# %%
integer = talib.CDLIDENTICAL3CROWS(open_, high, low, close)

# %% [markdown]
# ### 5.7.33. CDLINNECK - In-Neck Pattern

# %%
integer = talib.CDLINNECK(open_, high, low, close)

# %% [markdown]
# ### 5.7.34. CDLINVERTEDHAMMER - Inverted Hammer

# %%
integer = talib.CDLINVERTEDHAMMER(open_, high, low, close)

# %% [markdown]
# ### 5.7.35. CDLKICKING - Kicking

# %%
integer = talib.CDLKICKING(open_, high, low, close)

# %% [markdown]
# ### 5.7.36. CDLKICKINGBYLENGTH - Kicking - bull/bear determined by the longer marubozu

# %%
integer = talib.CDLKICKINGBYLENGTH(open_, high, low, close)

# %% [markdown]
# ### 5.7.37. CDLLADDERBOTTOM - Ladder Bottom

# %%
integer = talib.CDLLADDERBOTTOM(open_, high, low, close)

# %% [markdown]
# ### 5.7.38. CDLLONGLEGGEDDOJI - Long Legged Doji

# %%
integer = talib.CDLLONGLEGGEDDOJI(open_, high, low, close)

# %% [markdown]
# ### 5.7.39. CDLLONGLINE - Long Line Candle

# %%
integer = talib.CDLLONGLINE(open_, high, low, close)

# %% [markdown]
# ### 5.7.40. CDLMARUBOZU - Marubozu

# %%
integer = talib.CDLMARUBOZU(open_, high, low, close)

# %% [markdown]
# ### 5.7.41. CDLMATCHINGLOW - Matching Low

# %%
integer = talib.CDLMATCHINGLOW(open_, high, low, close)

# %% [markdown]
# ### 5.7.42. CDLMATHOLD - Mat Hold

# %%
integer = talib.CDLMATHOLD(open_, high, low, close, penetration=0)

# %% [markdown]
# ### 5.7.43. CDLMORNINGDOJISTAR - Morning Doji Star

# %%
integer = talib.CDLMORNINGDOJISTAR(open_, high, low, close, penetration=0)

# %% [markdown]
# ### 5.7.44. CDLMORNINGSTAR - Morning Star

# %%
integer = talib.CDLMORNINGSTAR(open_, high, low, close, penetration=0)

# %% [markdown]
# ### 5.7.45. CDLONNECK - On-Neck Pattern

# %%
integer = talib.CDLONNECK(open_, high, low, close)

# %% [markdown]
# ### 5.7.46. CDLPIERCING - Piercing Pattern

# %%
integer = talib.CDLPIERCING(open_, high, low, close)

# %% [markdown]
# ### 5.7.47. CDLRICKSHAWMAN - Rickshaw Man

# %%
integer = talib.CDLRICKSHAWMAN(open_, high, low, close)

# %% [markdown]
# ### 5.7.48. CDLRISEFALL3METHODS - Rising/Falling Three Methods

# %%
integer = talib.CDLRISEFALL3METHODS(open_, high, low, close)

# %% [markdown]
# ### 5.7.49. CDLSEPARATINGLINES - Separating Lines

# %%
integer = talib.CDLSEPARATINGLINES(open_, high, low, close)

# %% [markdown]
# ### 5.7.50. CDLSHOOTINGSTAR - Shooting Star

# %%
integer = talib.CDLSHOOTINGSTAR(open_, high, low, close)

# %% [markdown]
# ### 5.7.51. CDLSHORTLINE - Short Line Candle

# %%
integer = talib.CDLSHORTLINE(open_, high, low, close)

# %% [markdown]
# ### 5.7.52. CDLSPINNINGTOP - Spinning Top

# %%
integer = talib.CDLSPINNINGTOP(open_, high, low, close)

# %% [markdown]
# ### 5.7.53. CDLSTALLEDPATTERN - Stalled Pattern

# %%
integer = talib.CDLSTALLEDPATTERN(open_, high, low, close)

# %% [markdown]
# ### 5.7.54. CDLSTICKSANDWICH - Stick Sandwich

# %%
integer = talib.CDLSTICKSANDWICH(open_, high, low, close)

# %% [markdown]
# ### 5.7.55. CDLTAKURI - Takuri (Dragonfly Doji with very long lower shadow)

# %%
integer = talib.CDLTAKURI(open_, high, low, close)

# %% [markdown]
# ### 5.7.56. CDLTASUKIGAP - Tasuki Gap

# %%
integer = talib.CDLTASUKIGAP(open_, high, low, close)

# %% [markdown]
# ### 5.7.57. CDLTHRUSTING - Thrusting Pattern

# %%
integer = talib.CDLTHRUSTING(open_, high, low, close)

# %% [markdown]
# ### 5.7.58. CDLTRISTAR - Tristar Pattern

# %%
integer = talib.CDLTRISTAR(open_, high, low, close)

# %% [markdown]
# ### 5.7.59. CDLUNIQUE3RIVER - Unique 3 River

# %%
integer = talib.CDLUNIQUE3RIVER(open_, high, low, close)

# %% [markdown]
# ### 5.7.60. CDLUPSIDEGAP2CROWS - Upside Gap Two Crows

# %%
integer = talib.CDLUPSIDEGAP2CROWS(open_, high, low, close)

# %% [markdown]
# ### 5.7.61. CDLXSIDEGAP3METHODS - Upside/Downside Gap Three Methods

# %%
integer = talib.CDLXSIDEGAP3METHODS(open_, high, low, close)

# %% [markdown]
# ## [5.8. Statistic Functions](http://mrjbq7.github.io/ta-lib/func_groups/statistic_functions.html)

# %% [raw]
# BETA                 Beta
# CORREL               Pearson's Correlation Coefficient (r)
# LINEARREG            Linear Regression
# LINEARREG_ANGLE      Linear Regression Angle
# LINEARREG_INTERCEPT  Linear Regression Intercept
# LINEARREG_SLOPE      Linear Regression Slope
# STDDEV               Standard Deviation
# TSF                  Time Series Forecast
# VAR                  Variance

# %% [markdown]
# Statistic Functions
# ### 5.8.1. BETA - Beta

# %%
real = talib.BETA(high, low, timeperiod=5)

# %% [markdown]
# Learn more about the Beta at tadoc.org.

# %% [markdown]
# ### 5.8.2. CORREL - Pearson's Correlation Coefficient (r)

# %%
real = talib.CORREL(high, low, timeperiod=30)

# %% [markdown]
# Learn more about the Pearson's Correlation Coefficient (r) at tadoc.org.

# %% [markdown]
# ### 5.8.3. LINEARREG - Linear Regression

# %%
real = talib.LINEARREG(close, timeperiod=14)

# %% [markdown]
# Learn more about the Linear Regression at tadoc.org.

# %% [markdown]
# ### 5.8.4. LINEARREG_ANGLE - Linear Regression Angle

# %%
real = talib.LINEARREG_ANGLE(close, timeperiod=14)

# %% [markdown]
# Learn more about the Linear Regression Angle at tadoc.org.

# %% [markdown]
# ### 5.8.5. LINEARREG_INTERCEPT - Linear Regression Intercept

# %%
real = talib.LINEARREG_INTERCEPT(close, timeperiod=14)

# %% [markdown]
# Learn more about the Linear Regression Intercept at tadoc.org.

# %% [markdown]
# ### 5.8.6. LINEARREG_SLOPE - Linear Regression Slope

# %%
real = talib.LINEARREG_SLOPE(close, timeperiod=14)

# %% [markdown]
# Learn more about the Linear Regression Slope at tadoc.org.

# %% [markdown]
# ### 5.8.7. STDDEV - Standard Deviation

# %%
real = talib.STDDEV(close, timeperiod=5, nbdev=1)

# %% [markdown]
# Learn more about the Standard Deviation at tadoc.org.

# %% [markdown]
# ### 5.8.8. TSF - Time Series Forecast

# %%
real = talib.TSF(close, timeperiod=14)

# %% [markdown]
# Learn more about the Time Series Forecast at tadoc.org.

# %% [markdown]
# ### 5.8.9. VAR - Variance

# %%
real = talib.VAR(close, timeperiod=5, nbdev=1)

# %% [markdown]
# Learn more about the Variance at tadoc.org.

# %% [markdown]
# ## [5.9. Math Transform](http://mrjbq7.github.io/ta-lib/func_groups/math_transform.html)

# %% [raw]
# ACOS                 Vector Trigonometric ACos
# ASIN                 Vector Trigonometric ASin
# ATAN                 Vector Trigonometric ATan
# CEIL                 Vector Ceil
# COS                  Vector Trigonometric Cos
# COSH                 Vector Trigonometric Cosh
# EXP                  Vector Arithmetic Exp
# FLOOR                Vector Floor
# LN                   Vector Log Natural
# LOG10                Vector Log10
# SIN                  Vector Trigonometric Sin
# SINH                 Vector Trigonometric Sinh
# SQRT                 Vector Square Root
# TAN                  Vector Trigonometric Tan
# TANH                 Vector Trigonometric Tanh

# %% [markdown]
# Math Transform Functions

# %% [markdown]
# ### 5.9.1. ACOS - Vector Trigonometric ACos

# %%
real = talib.ACOS(close)

# %% [markdown]
# ### 5.9.1. ASIN - Vector Trigonometric ASin

# %%
real = talib.ASIN(close)

# %% [markdown]
# ### 5.9.1. ATAN - Vector Trigonometric ATan

# %%
real = talib.ATAN(close)

# %% [markdown]
# ### 5.9.1. CEIL - Vector Ceil

# %%
real = talib.CEIL(close)

# %% [markdown]
# ### 5.9.1. COS - Vector Trigonometric Cos

# %%
real = talib.COS(close)

# %% [markdown]
# ### 5.9.1. COSH - Vector Trigonometric Cosh

# %%
real = talib.COSH(close)

# %% [markdown]
# ### 5.9.1. EXP - Vector Arithmetic Exp

# %%
real = talib.EXP(close)

# %% [markdown]
# ### 5.9.1. FLOOR - Vector Floor

# %%
real = talib.FLOOR(close)

# %% [markdown]
# ### 5.9.1. LN - Vector Log Natural

# %%
real = talib.LN(close)

# %% [markdown]
# ### 5.9.1. LOG10 - Vector Log10

# %%
real = talib.LOG10(close)

# %% [markdown]
# ### 5.9.1. SIN - Vector Trigonometric Sin

# %%
real = talib.SIN(close)

# %% [markdown]
# ### 5.9.1. SINH - Vector Trigonometric Sinh

# %%
real = talib.SINH(close)

# %% [markdown]
# ### 5.9.1. SQRT - Vector Square Root

# %%
real = talib.SQRT(close)

# %% [markdown]
# ### 5.9.1. TAN - Vector Trigonometric Tan

# %%
real = talib.TAN(close)

# %% [markdown]
# ### 5.9.1. TANH - Vector Trigonometric Tanh

# %%
real = talib.TANH(close)

# %% [markdown]
# ## [5.10. Math Operators](http://mrjbq7.github.io/ta-lib/func_groups/math_operators.html)

# %% [raw]
# ADD                  Vector Arithmetic Add
# DIV                  Vector Arithmetic Div
# MAX                  Highest value over a specified period
# MAXINDEX             Index of highest value over a specified period
# MIN                  Lowest value over a specified period
# MININDEX             Index of lowest value over a specified period
# MINMAX               Lowest and highest values over a specified period
# MINMAXINDEX          Indexes of lowest and highest values over a specified period
# MULT                 Vector Arithmetic Mult
# SUB                  Vector Arithmetic Substraction
# SUM                  Summation

# %% [markdown]
# Math Operator Functions

# %% [markdown]
# ### 5.10.1. ADD - Vector Arithmetic Add

# %%
real = talib.ADD(high, low)

# %% [markdown]
# ### 5.10.1. DIV - Vector Arithmetic Div

# %%
real = talib.DIV(high, low)

# %% [markdown]
# ### 5.10.1. MAX - Highest value over a specified period

# %%
real = talib.MAX(close, timeperiod=30)

# %% [markdown]
# ### 5.10.1. MAXINDEX - Index of highest value over a specified period

# %%
integer = talib.MAXINDEX(close, timeperiod=30)

# %% [markdown]
# ### 5.10.1. MIN - Lowest value over a specified period

# %%
real = talib.MIN(close, timeperiod=30)

# %% [markdown]
# ### 5.10.1. MININDEX - Index of lowest value over a specified period

# %%
integer = talib.MININDEX(close, timeperiod=30)

# %% [markdown]
# ### 5.10.1. MINMAX - Lowest and highest values over a specified period

# %%
min, talib.max = talib.MINMAX(close, timeperiod=30)

# %% [markdown]
# ### 5.10.1. MINMAXINDEX - Indexes of lowest and highest values over a specified period

# %%
minidx, talib.maxidx = talib.MINMAXINDEX(close, timeperiod=30)

# %% [markdown]
# ### 5.10.1. MULT - Vector Arithmetic Mult

# %%
real = talib.MULT(high, low)

# %% [markdown]
# ### 5.10.1. SUB - Vector Arithmetic Substraction

# %%
real = talib.SUB(high, low)

# %% [markdown]
# ### 5.10.1. SUM - Summation

# %%
real = talib.SUM(close, timeperiod=30)
