# %% [markdown]
# #### Carregando uma Planilha Existente

# %%
from openpyxl import load_workbook
import pandas as pd
caminho = 'mascara_excel_v002.xlsx'
arquivo_excel = load_workbook(caminho)

# %% [markdown]
# #### Composição de um dataframe com os dados do excel

# %% [markdown]
# ##### Lista de worksheets

# %%
ls_work_sheets = []
for i in arquivo_excel:
    ls_work_sheets += [i]

# %%
ls_work_sheets
# Out:
# [<Worksheet "MÁSCARA - CEFAG EMPREENDIMENTOS">,
#  <Worksheet "HENRIQUE">,
#  <Worksheet "COMPOSIÇÃO">]

# %%
print(arquivo_excel.sheetnames)
# Out:
# ['MÁSCARA - CEFAG EMPREENDIMENTOS', 'HENRIQUE', 'COMPOSIÇÃO']

# %% [markdown]
# #### Insere as informaçães de uma planilha do excel em um dataframe

# %%
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_rows", None)
df_0 = pd.DataFrame(ls_work_sheets[0].values)
df_0
# Out:
#                                                                                     0  \
# 0   MÁSCARA - CEFAG EMPREENDIMENTOS IMOBILIARIOS SPE LTDA - E01_S353_À_S360_CEMARA II
# 1                                                                           Descrição
# 2                                                                                None
# 3                                         Referência: 1. VP dos Direitos Creditórios
# 4                                                                                None
# 5                                                                                None
# 6                                                                                None
# 7                                                                                None
# 8                                                                                None
# 9                                                                                None
# ...

# %%
df_1 = pd.DataFrame(ls_work_sheets[1].values)
df_1
# Out:
#                                                                                    0   \
# 0   MÁSCARA - CEFAG EMPREENDIMENTOS IMOBILIARIOS SPE LTDA - E01_S353_À_S360_CEMARA II
# 1                                                                           Descrição
# 2                                                                                None
# 3                                         Referência: 1. VP dos Direitos Creditórios
# 4                                                                                None
# 5                                                                                None
# 6                                                                                None
# 7                                                                                None
# 8                                                                                None
# 9                                                                                None
# ...

# %%
df_2 = pd.DataFrame(ls_work_sheets[2].values)
df_2
# Out:
#                                                                                    0   \
# 0   MÁSCARA - CEFAG EMPREENDIMENTOS IMOBILIARIOS SPE LTDA - E01_S353_À_S360_CEMARA II
# 1                                                                           Descrição
# 2                                                                                None
# 3                                         Referência: 1. VP dos Direitos Creditórios
# 4                                                                                None
# 5                                                                                None
# 6                                                                                None
# 7                                                                                None
# 8                                                                                None
# 9                                                                                None
# ...

# %%
df_2[0][0] = "sdhfiaohfõ"

# %%
print(df_2[0][0])
# Out:
# sdhfiaohfõ

# %%
arquivo_excel["COMPOSIÇÃO"] =
# Out:
# <Worksheet "COMPOSIÇÃO">

# %%
arquivo_excel.active
# Out:
# <Worksheet "COMPOSIÇÃO">

# %%
arquivo_excel.active = df_0

# %% [markdown]
# #### [How to Write Pandas DataFrame to Excel Sheet?](https://pythonexamples.org/pandas-write-dataframe-to-excel-sheet/)

# %%
from openpyxl import load_workbook

wb = load_workbook('formatacao.xlsx')

# %%
ls_work_sheets[2] = df_2

# %% [raw]
# arquivo_excel.save("pandas_openpyxl.xlsx")

# %%
# Write each dataframe to a different worksheet.
df_2.to_excel(writer, sheet_name='Sheet1')

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('mascara_excel_v001.xlsx', engine='xlsxwriter')
writer

# %%
# Convert the dataframe to an XlsxWriter Excel object.
df_2.to_excel(writer, sheet_name="COMPOSIÇÃO")

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %% [markdown]
# #### Salvando Sua Planilha

# %%
arquivo_excel.save("mascara_excel_v004.xlsx")
